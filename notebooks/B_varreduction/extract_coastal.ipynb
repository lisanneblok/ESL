# %%
{
  "dataset_id": "EO:EEA:DAT:COASTALZONES",
  "productType": "Coastal Zones 2018",
  "itemsPerPage": 200,
  "startIndex": 0
}
# Out:
# {'dataset_id': 'EO:EEA:DAT:COASTALZONES',
#  'productType': 'Coastal Zones 2018',
#  'itemsPerPage': 200,
#  'startIndex': 0}
