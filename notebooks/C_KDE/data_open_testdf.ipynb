# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import geopandas as gpd
import pandas as pd

# %%
stats_df = pd.read_csv("/Users/lb962/Documents/GitHub/ESL_stats/data/processed/all_numerical_vars_bearing.csv")

# %%
# Load the GeoPackage (Coastal Vulnerability Data)
gpkg_path = "../../data/EMODNET/coastal_type/EMODnetCoastalType.gpkg"
gdf = gpd.read_file(gpkg_path)

# Convert CRS to EPSG:4326 (lat/lon)
gdf = gdf.to_crs(epsg=4326)
# Out:
# /Users/lb962/miniconda3/envs/telec_env/lib/python3.10/site-packages/pyogrio/geopandas.py:265: UserWarning: More than one layer found in 'EMODnetCoastalType.gpkg': 'Original' (default), '02', '2', '005', '05', '015', '0025', '01', '1', 'layer_styles'. Specify layer parameter to avoid this warning.
#   result = read_func(

# %%
path = "/Users/lb962/Downloads/EMODnet_Bathymetry_2024_coastlines/Europe_2024_OSM/Coastline_Europe_2024_OSM.shp"

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# Path to your shapefile
path = "/Users/lb962/Downloads/EMODnet_Bathymetry_2024_coastlines/Europe_2024_OSM/Coastline_Europe_2024_OSM.shp"

# Read shapefile
gdf = gpd.read_file(path)

# Quick inspection
print(gdf.head())
print(gdf.crs)

# Plot
fig, ax = plt.subplots(figsize=(10, 10))
gdf.plot(ax=ax, linewidth=0.5)

ax.set_title("Europe Coastline 2024 (OSM)")
ax.set_axis_off()

plt.show()
# Out:
#                LAYER  FID  Shape_Leng  Shape_Area  \
# 0  Unknown Area Type  0.0         NaN         NaN
# 1  Unknown Area Type  1.0         NaN         NaN
# 2  Unknown Area Type  2.0         NaN         NaN
# 3  Unknown Area Type  3.0         NaN         NaN
# 4  Unknown Area Type  4.0         NaN         NaN
#
#                                             geometry
# 0  POLYGON ((-4.94237 55.72545, -4.94192 55.72558...
# 1  POLYGON ((-4.94051 55.72458, -4.94049 55.72407...
# 2  POLYGON ((-4.7329 55.52496, -4.7338 55.52495, ...
# 3  POLYGON ((-4.95385 55.1629, -4.95388 55.16341,...
# 4  POLYGON ((-1.75363 50.72293, -1.75358 50.72303...
# EPSG:4326
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[52], line 16
#      14 # Plot
#      15 fig, ax = plt.subplots(figsize=(10, 10))
# ---> 16 gdf.plot(ax=ax, linewidth=0.5)
#      18 ax.set_title("Europe Coastline 2024 (OSM)")
#      19 ax.set_axis_off()
#
# File ~/miniconda3/envs/telec_env/lib/python3.10/site-packages/geopandas/plotting.py:968, in GeoplotAccessor.__call__(self, *args, **kwargs)
#     966 kind = kwargs.pop("kind", "geo")
#     967 if kind == "geo":
# --> 968     return plot_dataframe(data, *args, **kwargs)
#     969 if kind in self._pandas_kinds:
#     970     # Access pandas plots
#     971     return PlotAccessor(data)(kind=kind, **kwargs)
#
# File ~/miniconda3/envs/telec_env/lib/python3.10/site-packages/geopandas/plotting.py:690, in plot_dataframe(df, column, cmap, color, ax, cax, categorical, legend, scheme, k, vmin, vmax, markersize, figsize, legend_kwds, categories, classification_kwds, missing_kwds, aspect, autolim, **style_kwds)
#     687     markersize = df[markersize].values
#     689 if column is None:
# --> 690     return plot_series(
#     691         df.geometry,
#     692         cmap=cmap,
#     693         color=color,
#     694         ax=ax,
#     695         figsize=figsize,
#     696         markersize=markersize,
#     697         aspect=aspect,
#     698         autolim=autolim,
#     699         **style_kwds,
#     700     )
#     702 # To accept pd.Series and np.arrays as column
#     703 if isinstance(column, (np.ndarray, pd.Series)):
#
# File ~/miniconda3/envs/telec_env/lib/python3.10/site-packages/geopandas/plotting.py:452, in plot_series(s, cmap, color, ax, figsize, aspect, autolim, **style_kwds)
#     449         facecolor = color_
#     451     values_ = values[poly_idx] if cmap else None
# --> 452     _plot_polygon_collection(
#     453         ax,
#     454         polys,
#     455         values_,
#     456         facecolor=facecolor,
#     457         cmap=cmap,
#     458         autolim=autolim,
#     459         **style_kwds,
#     460     )
#     462 # plot all LineStrings and MultiLineString components in same collection
#     463 lines = expl_series[line_idx]
#
# File ~/miniconda3/envs/telec_env/lib/python3.10/site-packages/geopandas/plotting.py:155, in _plot_polygon_collection(ax, geoms, values, color, cmap, vmin, vmax, autolim, **kwargs)
#     125 """
#     126 Plots a collection of Polygon and MultiPolygon geometries to `ax`
#     127
#    (...)
#     151 collection : matplotlib.collections.Collection that was plotted
#     152 """
#     153 from matplotlib.collections import PatchCollection
# --> 155 geoms, multiindex = _sanitize_geoms(geoms)
#     156 if values is not None:
#     157     values = np.take(values, multiindex, axis=0)
#
# File ~/miniconda3/envs/telec_env/lib/python3.10/site-packages/geopandas/plotting.py:47, in _sanitize_geoms(geoms, prefix)
#      45         components.append(poly)
#      46         component_index.append(ix)
# ---> 47 elif geom is None or geom.is_empty:
#      48     continue
#      49 else:
#
# File ~/miniconda3/envs/telec_env/lib/python3.10/site-packages/shapely/geometry/base.py:724, in BaseGeometry.is_empty(self)
#     721 @property
#     722 def is_empty(self):
#     723     """True if the set of points in this geometry is empty, else False."""
# --> 724     return bool(shapely.is_empty(self))
#
# File ~/miniconda3/envs/telec_env/lib/python3.10/site-packages/shapely/decorators.py:87, in multithreading_enabled.<locals>.wrapped(*args, **kwargs)
#      85     for arr in array_args:
#      86         arr.flags.writeable = False
# ---> 87     return func(*args, **kwargs)
#      88 finally:
#      89     for arr, old_flag in zip(array_args, old_flags):
#
# File ~/miniconda3/envs/telec_env/lib/python3.10/site-packages/shapely/predicates.py:208, in is_empty(geometry, **kwargs)
#     181 @multithreading_enabled
#     182 def is_empty(geometry, **kwargs):
#     183     """Return True if a geometry is an empty point, polygon, etc.
#     184
#     185     Parameters
#    (...)
#     206
#     207     """
# --> 208     return lib.is_empty(geometry, **kwargs)
#
# KeyboardInterrupt:

# %%
! pip install fiona
# Out:
# Collecting fiona
#   Downloading fiona-1.10.1-cp310-cp310-macosx_11_0_arm64.whl.metadata (56 kB)
# Requirement already satisfied: attrs>=19.2.0 in /Users/lb962/miniconda3/envs/telec_env/lib/python3.10/site-packages (from fiona) (24.2.0)
# Requirement already satisfied: certifi in /Users/lb962/miniconda3/envs/telec_env/lib/python3.10/site-packages (from fiona) (2025.4.26)
# Requirement already satisfied: click~=8.0 in /Users/lb962/miniconda3/envs/telec_env/lib/python3.10/site-packages (from fiona) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in /Users/lb962/miniconda3/envs/telec_env/lib/python3.10/site-packages (from fiona) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /Users/lb962/miniconda3/envs/telec_env/lib/python3.10/site-packages (from fiona) (0.7.2)
# Downloading fiona-1.10.1-cp310-cp310-macosx_11_0_arm64.whl (14.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.8/14.8 MB 702.8 kB/s eta 0:00:0000:0100:01
# Installing collected packages: fiona
# Successfully installed fiona-1.10.1

# %%
import fiona
import geopandas as gpd
gpkg_path = "/Users/lb962/Downloads/Results 2/CZ_2018_DU004_3035_V010/Data/CZ_2018_DU004_3035_V010.gpkg"
layers = fiona.listlayers(gpkg_path)
print(layers)
# Out:
# ['CZ_2018_DU004_3035_V010']

# %%
gdf = gpd.read_file(gpkg_path, layer="CZ_2018_DU004_3035_V010")

# %%
coast = gdf

# %%
df = stats_df

# %%
import pandas as pd
import geopandas as gpd

#gpkg_path = "/Users/lb962/Downloads/Results 2/CZ_2018_DU004_3035_V010/Data/CZ_2018_DU004_3035_V010.gpkg"
# 3) Convert df -> GeoDataFrame of points in WGS84
pts = gpd.GeoDataFrame(
    df.copy(),
    geometry=gpd.points_from_xy(df["lon"], df["lat"]),
    crs="EPSG:4326"
)

# 4) Reproject POINTS to match polygons CRS (fast)
pts_3035 = pts.to_crs(coast.crs)

# 5) Spatial join: which polygon contains each point?
# Choose the columns you want back from the coastal layer:
cols_to_add = ["DU", "CODE_1_18", "CODE_2_18", "CODE_3_18", "CODE_4_18", "CODE_5_18", "COMMENT_18"]
joined = gpd.sjoin(
    pts_3035,
    coast[cols_to_add + ["geometry"]],
    how="left",
    predicate="within"   # points within polygons
)

# 6) Back to a normal DataFrame (drop geometry if you want)
result = pd.DataFrame(joined.drop(columns=["geometry", "index_right"]))

# %%
result.to_csv("copernicus_stations.csv")

# %%
result = pd.read_csv("copernicus_stations.csv")

# %%
from pathlib import Path
import re
import pandas as pd
import xml.etree.ElementTree as ET

def read_text_best_effort(path: str) -> str:
    data = Path(path).read_bytes()
    for enc in ("utf-8", "utf-8-sig", "latin-1"):
        try:
            return data.decode(enc)
        except UnicodeDecodeError:
            pass
    return data.decode("utf-8", errors="replace")

def parse_qml(qml_path: str) -> pd.DataFrame:
    """
    Extract (value -> label) pairs from QGIS .qml styles.
    Works for categorized renderers and many rule-based styles.
    """
    text = read_text_best_effort(qml_path)
    root = ET.fromstring(text)

    pairs = []

    # 1) Categorized renderer: <category value="..." label="..."/>
    for cat in root.findall(".//category"):
        val = cat.attrib.get("value")
        lab = cat.attrib.get("label")
        if val is not None and lab is not None:
            pairs.append((val.strip(), lab.strip(), "qml:category"))

    # 2) Rule-based renderer often has <rule filter="..." label="...">
    # Try to parse simple filters like: "CODE_5_18" = '1234'
    rule_re = re.compile(r'["\']?([\w:]+)["\']?\s*=\s*[\'"]([^\'"]+)[\'"]')
    for rule in root.findall(".//rule"):
        lab = rule.attrib.get("label") or rule.attrib.get("name")
        flt = rule.attrib.get("filter")
        if lab and flt:
            m = rule_re.search(flt)
            if m:
                code = m.group(2).strip()
                pairs.append((code, lab.strip(), "qml:rule"))

    df = pd.DataFrame(pairs, columns=["code", "label", "source"])
    if df.empty:
        return df
    df["code"] = df["code"].astype(str).str.strip()
    df["label"] = df["label"].astype(str).str.strip()
    return df.drop_duplicates(subset=["code", "label"])

def parse_sld(sld_path: str) -> pd.DataFrame:
    """
    Extract (filter literal -> rule Title/Name) pairs from SLD.
    Typical structure:
      <Rule>
        <Name>...</Name> or <Title>...</Title>
        <ogc:Filter> ... <ogc:Literal>CODE</ogc:Literal> ...
      </Rule>
    """
    text = read_text_best_effort(sld_path)
    root = ET.fromstring(text)

    # Namespace-aware search: capture namespaces if present
    ns = {}
    for k, v in root.attrib.items():
        if k.startswith("xmlns:"):
            ns[k.split(":", 1)[1]] = v
    # Common SLD/OGC namespaces
    ns.setdefault("sld", "http://www.opengis.net/sld")
    ns.setdefault("ogc", "http://www.opengis.net/ogc")

    pairs = []

    # Find all Rule elements, regardless of namespace
    for rule in root.findall(".//{*}Rule"):
        title = None
        name = None
        for child in list(rule):
            tag = child.tag.split("}")[-1].lower()
            if tag == "title" and (child.text or "").strip():
                title = child.text.strip()
            if tag == "name" and (child.text or "").strip():
                name = child.text.strip()
        label = title or name

        # Pull literals from any Filter; for equality filters there is usually one literal
        literals = [lit.text.strip() for lit in rule.findall(".//{*}Literal") if (lit.text or "").strip()]

        if label and literals:
            # Heuristic: often the code is the last literal (first might be field name in some encodings)
            # Keep all candidate literals; we’ll filter later.
            for lit in literals:
                pairs.append((lit, label, "sld:rule"))

    df = pd.DataFrame(pairs, columns=["code", "label", "source"])
    if df.empty:
        return df
    df["code"] = df["code"].astype(str).str.strip()
    df["label"] = df["label"].astype(str).str.strip()

    # Filter out non-code literals (e.g., field names) by keeping ones that contain at least one digit
    df = df[df["code"].str.contains(r"\d", regex=True)]

    return df.drop_duplicates(subset=["code", "label"])

def detect_field_from_qml(qml_path: str):
    text = read_text_best_effort(qml_path)
    root = ET.fromstring(text)

    rv2 = root.find(".//renderer-v2")
    if rv2 is not None:
        return rv2.attrib.get("attr") or rv2.attrib.get("attribute")

    # fallback: inspect rule filters
    for rule in root.findall(".//rule"):
        flt = rule.attrib.get("filter")
        if flt:
            m = re.search(r'"([^"]+)"', flt)
            if m:
                return m.group(1)
    return None

def parse_lyr(lyr_path: str) -> pd.DataFrame:
    """
    Best-effort extraction from ESRI .lyr. Some are XML-ish, some are binary.
    We'll scan text for value/label patterns.
    """
    text = read_text_best_effort(lyr_path)

    pairs = []

    # Common attribute patterns in XML-ish layer files
    patterns = [
        re.compile(r'value="([^"]+)"[^>]*label="([^"]+)"', re.IGNORECASE),
        re.compile(r'label="([^"]+)"[^>]*value="([^"]+)"', re.IGNORECASE),
        re.compile(r"<Value>([^<]+)</Value>\s*<Label>([^<]+)</Label>", re.IGNORECASE),
        re.compile(r"<Label>([^<]+)</Label>\s*<Value>([^<]+)</Value>", re.IGNORECASE),
    ]

    def looks_like_code(s: str) -> bool:
        s = s.strip()
        return bool(re.fullmatch(r"[0-9A-Za-z_.-]+", s)) and any(ch.isdigit() for ch in s)

    for pat in patterns:
        for m in pat.finditer(text):
            a, b = m.group(1).strip(), m.group(2).strip()
            if looks_like_code(a) and not looks_like_code(b):
                pairs.append((a, b, "lyr"))
            elif looks_like_code(b) and not looks_like_code(a):
                pairs.append((b, a, "lyr"))
            else:
                # ambiguous, store as-is
                pairs.append((a, b, "lyr"))

    df = pd.DataFrame(pairs, columns=["code", "label", "source"])
    if df.empty:
        return df
    df["code"] = df["code"].astype(str).str.strip()
    df["label"] = df["label"].astype(str).str.strip()
    # Keep code-like rows
    df = df[df["code"].str.contains(r"\d", regex=True)]
    return df.drop_duplicates(subset=["code", "label"])

def build_style_lookup(files: list[str]) -> pd.DataFrame:
    """
    files: list of paths to .qml/.sld/.lyr
    Returns: DataFrame(code, label, source)
    """
    parts = []
    for f in files:
        ext = Path(f).suffix.lower()
        if ext == ".qml":
            parts.append(parse_qml(f))
        elif ext == ".sld":
            parts.append(parse_sld(f))
        elif ext == ".lyr":
            parts.append(parse_lyr(f))
        else:
            raise ValueError(f"Unsupported style file: {f}")

    lut = pd.concat([p for p in parts if p is not None and not p.empty], ignore_index=True)
    if lut.empty:
        return lut

    # Prefer QML over SLD over LYR if duplicates exist
    rank = {"qml:category": 0, "qml:rule": 1, "sld:rule": 2, "lyr": 3}
    lut["rank"] = lut["source"].map(rank).fillna(9).astype(int)
    lut = (lut.sort_values(["code", "rank"])
              .drop_duplicates(subset=["code"], keep="first")
              .drop(columns=["rank"])
              .reset_index(drop=True))
    return lut

# Example style file list (edit to your actual paths)
style_files = [
    r"/Users/lb962/Downloads/Results 2/CZ_2018_DU004_3035_V010/Symbology/CZ_LCLU_2018.qml",
    r"/Users/lb962/Downloads/Results 2/CZ_2018_DU004_3035_V010/Symbology/CZ_LCLU_2018.sld",
    r"/Users/lb962/Downloads/Results 2/CZ_2018_DU004_3035_V010/Symbology/CZ_LCLU_2018.lyr",
]

lut = build_style_lookup(style_files)
# make types consistent
result["CODE_5_18"] = result["CODE_5_18"].astype(str).str.strip()
lut["code"] = lut["code"].astype(str).str.strip()

#result = result.merge(
 #   lut.rename(columns={"code": "CODE_5_18", "label": "coastal_type"}),
 #   on="CODE_5_18",
 #   how="left"
#)

# %% [markdown]
# # filter non coastal ones

# %%
coastal_keep = [
    "Sandy beaches",
    "Shingle beaches",
    "Dunes",
    "Coastal cliffs",
    "Bare rocks and outcrops",
    "Sparse vegetation on sands",
    "Sparse vegetation on rocks",
    "Salt marshes",
    "Salines",
    "Intertidal flats",
    "River banks",
    "Lagoons",
    "Estuaries",
    "Marine inlets and fjords",
    "Coastal waters",
    "Open sea",
    "Cargo port",
    "Passenger port",
    "Fishing port",
    "Naval port",
    "Marinas",
    "Local multi-functional harbours",
    "Shipyards",
]

lut_coastal = lut[lut["label"].isin(coastal_keep)].copy()

result2 = result.merge(
    lut_coastal.rename(columns={"code": "CODE_5_18", "label": "coastal_type"}),
    on="CODE_5_18",
    how="left"
)

# %%
import numpy as np
import pandas as pd
from sklearn.neighbors import BallTree

result2 = result2.copy()

# change these if your column names differ
LAT_COL = "lat"
LON_COL = "lon"
TARGET_COL = "coastal_type"

# keep only rows with valid coordinates
has_coords = result2[LAT_COL].notna() & result2[LON_COL].notna()

# rows that already have a coastal type = reference points
ref = result2.loc[
    has_coords & result2[TARGET_COL].notna(),
    [LAT_COL, LON_COL, TARGET_COL]
].copy()

# rows to fill
miss = result2.loc[
    has_coords & result2[TARGET_COL].isna(),
    [LAT_COL, LON_COL]
].copy()

if len(ref) == 0:
    raise ValueError("No non-null coastal_type rows with valid lat/lon found.")

if len(miss) > 0:
    # BallTree with haversine needs radians
    ref_coords = np.radians(ref[[LAT_COL, LON_COL]].to_numpy())
    miss_coords = np.radians(miss[[LAT_COL, LON_COL]].to_numpy())

    tree = BallTree(ref_coords, metric="haversine")
    dist, ind = tree.query(miss_coords, k=1)

    # nearest label
    nearest_labels = ref.iloc[ind[:, 0]][TARGET_COL].to_numpy()

    # distance in km (Earth radius ~6371 km)
    nearest_dist_km = dist[:, 0] * 6371.0

    # write back
    result2.loc[miss.index, TARGET_COL] = nearest_labels
    result2.loc[miss.index, "coastal_type_fill_dist_km"] = nearest_dist_km

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

df = result2.dropna(subset=["lat", "lon"]).copy()

categories = df["coastal_type"].fillna("unknown").unique()
colors = plt.cm.tab20(range(len(categories)))

color_map = dict(zip(categories, colors))

fig = plt.figure(figsize=(12, 9))
ax = plt.axes(projection=ccrs.PlateCarree())

ax.coastlines()
ax.add_feature(cfeature.BORDERS, linewidth=0.5)

for cat in categories:
    subset = df[df["coastal_type"].fillna("unknown") == cat]
    ax.scatter(
        subset["lon"],
        subset["lat"],
        label=cat,
        s=80,
        transform=ccrs.PlateCarree()
    )

ax.legend(title="Coastal Type", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.title("Coastal Classification")
plt.show()

# %%
import geopandas as gpd
import pandas as pd

# coast_polys: your original CZ polygons layer (EPSG:3035)
# Example:
# coast_polys = gpd.read_file(gpkg_path, layer="...")   # keep native CRS (3035)

# Add labels to the polygon layer (same mapping you used on points)
coast_polys = coast_polys.merge(
    lut_coastal.rename(columns={"code": "CODE_5_18", "label": "coastal_type"})[["CODE_5_18", "coastal_type"]],
    on="CODE_5_18",
    how="inner"   # keep only coastal classes
)

# (optional) keep only needed columns to speed things up
coast_polys = coast_polys[["CODE_5_18", "coastal_type", "geometry"]].copy()

# %%
result2.coastal_type.unique()
# Out:
# array([nan, '84200 Coastal waters', '84100 Open sea', '83200 Estuaries',
#        '72300 Intertidal flats', '72100 Salt marshes',
#        '62111 Sandy beaches', '83300 Marine inlets and fjords',
#        '61200 Sparse vegetation on rocks',
#        '63110 Bare rocks and outcrops', '63120 Coastal cliffs',
#        '61100 Sparse vegetation on sands'], dtype=object)

# %% [markdown]
# # EMODNET Coastal Type

# %%
import geopandas as gpd
import rasterio
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from rasterio.transform import from_origin

# Load the GeoPackage (Coastal Vulnerability Data)
gpkg_path = "../../data/EMODNET/coastal_type/EMODnetCoastalType.gpkg"
gdf = gpd.read_file(gpkg_path)

# Convert CRS to EPSG:4326 (lat/lon)
gdf = gdf.to_crs(epsg=4326)

# Check geometry type and assign latitude and longitude based on the geometry type
if gdf.geometry.geom_type.iloc[0] == 'Point':
    gdf['latitude'] = gdf.geometry.y
    gdf['longitude'] = gdf.geometry.x
else:
    # If it's not a point, calculate the centroid for non-Point geometries
    gdf['latitude'] = gdf.geometry.centroid.y
    gdf['longitude'] = gdf.geometry.centroid.x

# Load raster data (Wave and Current)
def load_raster_data(raster_path):
    with rasterio.open(raster_path) as raster:
        raster_data = raster.read(1)  # Read the first band
        transform = raster.transform  # Affine transform
        crs = raster.crs  # Coordinate reference system
        bounds = raster.bounds  # Get the bounds (min, max)
    return raster_data, transform, crs, bounds

# Paths to wave and current rasters
wave_raster_path_NC = "../../data/EMODNET/ke_waves_NC_withconf/ke_waves_NC_conf.tif"
wave_raster_path_atlantic = "../../data/EMODNET/ke_waves_NC_withconf/ke_waves_atlantic.tif"
current_raster_path = "../../data/EMODNET/ke_currents_atlantic_withconf/ke_currents_atlantic.tif"

# Load all raster data
wave_nc_data, wave_nc_transform, wave_nc_crs, wave_nc_bounds = load_raster_data(wave_raster_path_NC)
wave_atlantic_data, wave_atlantic_transform, wave_atlantic_crs, wave_atlantic_bounds = load_raster_data(wave_raster_path_atlantic)
current_data, current_transform, current_crs, current_bounds = load_raster_data(current_raster_path)

# Generate a grid of latitudes and longitudes for the raster data
def generate_lat_lon_grid(raster_data, raster_transform):
    rows, cols = raster_data.shape
    lon, lat = np.meshgrid(
        np.linspace(raster_transform[2], raster_transform[2] + raster_transform[0] * cols, cols),
        np.linspace(raster_transform[5] + raster_transform[4] * rows, raster_transform[5], rows)
    )
    return lat, lon

# Generate lat/lon grids for each raster
wave_nc_lat, wave_nc_lon = generate_lat_lon_grid(wave_nc_data, wave_nc_transform)
wave_atlantic_lat, wave_atlantic_lon = generate_lat_lon_grid(wave_atlantic_data, wave_atlantic_transform)
current_lat, current_lon = generate_lat_lon_grid(current_data, current_transform)

# Create DataFrame for wave and current data with latitude/longitude
def create_raster_df(lat, lon, data, variable_name):
    df = pd.DataFrame({
        'latitude': lat.flatten(),
        'longitude': lon.flatten(),
        variable_name: data.flatten()
    })
    return df

# Create DataFrames for wave and current data
wave_nc_df = create_raster_df(wave_nc_lat, wave_nc_lon, wave_nc_data, 'Wave_NC')
wave_atlantic_df = create_raster_df(wave_atlantic_lat, wave_atlantic_lon, wave_atlantic_data, 'Wave_Atlantic')
current_df = create_raster_df(current_lat, current_lon, current_data, 'Current')
# Out:
# /Users/lb962/miniconda3/envs/telec_env/lib/python3.10/site-packages/pyogrio/geopandas.py:265: UserWarning: More than one layer found in 'EMODnetCoastalType.gpkg': 'Original' (default), '02', '2', '005', '05', '015', '0025', '01', '1', 'layer_styles'. Specify layer parameter to avoid this warning.
#   result = read_func(
# /var/folders/2b/rpgq1g5d5qz2nhbpj5s4jnrc0000gq/T/ipykernel_56348/2086513627.py:21: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf['latitude'] = gdf.geometry.centroid.y
# /var/folders/2b/rpgq1g5d5qz2nhbpj5s4jnrc0000gq/T/ipykernel_56348/2086513627.py:22: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf['longitude'] = gdf.geometry.centroid.x

# %%
import numpy as np
import geopandas as gpd

CVI_gdf = gpd.read_file("../../data/EMODNET/coastal_vulnerability_resilience/20241218_original.gpkg")

# If CRS missing, set it (EMODnet often uses EPSG:3035)
if CVI_gdf.crs is None:
    CVI_gdf = CVI_gdf.set_crs(epsg=3035)

# Drop empties
CVI_gdf = CVI_gdf[~CVI_gdf.geometry.is_empty & CVI_gdf.geometry.notna()].copy()

# Fix invalid geometries (lines can still be "invalid")
CVI_gdf["geometry"] = CVI_gdf.geometry.make_valid()

# Reproject to lat/lon for Cartopy
CVI_gdf = CVI_gdf.to_crs(epsg=4326)

# (Optional but useful) remove any geometries with non-finite bounds
minx, miny, maxx, maxy = CVI_gdf.total_bounds
print("Bounds:", CVI_gdf.total_bounds)
# Out:
# Bounds: [-31.26757026   4.30520622  42.00064128  80.50602762]

# %%
GEV_clusters = stats_df

# %%
import geopandas as gpd

def clean_for_sjoin(gdf):
    # Remove leftover join columns that break future joins
    return gdf.drop(columns=["index_right", "index_left"], errors="ignore")

def to_proj(gdf, epsg=3857):
    # Ensure CRS exists
    if gdf.crs is None:
        raise ValueError("GeoDataFrame has no CRS set. Set it before projecting.")
    return gdf.to_crs(epsg=epsg)
PROJECTED_EPSG = 3857

# %%
GEV_gdf = gpd.GeoDataFrame(
    GEV_clusters.copy(),
    geometry=gpd.points_from_xy(GEV_clusters["lon"], GEV_clusters["lat"]),
    crs="EPSG:4326"
)

GEV_proj = GEV_gdf.to_crs(epsg=PROJECTED_EPSG)
GEV_proj = clean_for_sjoin(GEV_proj)

# %%
CVI_proj = clean_for_sjoin(CVI_gdf.to_crs(epsg=PROJECTED_EPSG))

GEV_all = gpd.sjoin_nearest(
    GEV_proj,
    CVI_proj[["CVI_Category", "geometry"]],
    how="left",
    distance_col="dist_to_CVI_m"
).drop(columns=["index_right"], errors="ignore")
morpho_proj = clean_for_sjoin(gdf)
morpho_proj = morpho_proj.to_crs(epsg=PROJECTED_EPSG)

GEV_all = gpd.sjoin_nearest(
    GEV_all,
    morpho_proj[["Morpho", "CoastType", "geometry"]],
    how="left",
    distance_col="dist_to_morpho_m"
).drop(columns=["index_right"], errors="ignore")

# %%
import geopandas as gpd

# Ensure lon/lat CRS for Cartopy
if GEV_all.crs is None:
    raise ValueError("GEV_all has no CRS. Set it (likely EPSG:4326) before plotting.")
GEV_all = GEV_all.to_crs(epsg=4326)

# %%
import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from matplotlib.cm import get_cmap

def extent_from_gdf(gdf, pad_deg=2.0):
    minx, miny, maxx, maxy = gdf.total_bounds
    return [minx - pad_deg, maxx + pad_deg, miny - pad_deg, maxy + pad_deg]

def plot_categorical_cartopy(
    gdf,
    col,
    title=None,
    extent=None,
    s=28,
    max_legend_items=20
):
    g = gdf[gdf[col].notna()].copy()
    if len(g) == 0:
        raise ValueError(f"No non-null values found in column '{col}'.")
    extent=[-20,15,48,65]
    #if extent is None:
       # extent = extent_from_gdf(g)

    categories = sorted(g[col].astype(str).unique())
    n = len(categories)

    # Use a colormap with many distinct colors
    cmap = get_cmap("tab20" if n <= 20 else "tab20b" if n <= 40 else "hsv")
    colors = {cat: cmap(i / max(1, n - 1)) for i, cat in enumerate(categories)}

    fig = plt.figure(figsize=(12, 9))
    ax = plt.axes(projection=ccrs.PlateCarree())
    ax.set_extent(extent, crs=ccrs.PlateCarree())

    ax.add_feature(cfeature.LAND, facecolor="lightgray", zorder=0)
    ax.add_feature(cfeature.COASTLINE, linewidth=0.6, zorder=1)
    ax.add_feature(cfeature.BORDERS, linewidth=0.3, zorder=1)

    # Plot each category separately (so legend works)
    for cat in categories:
        sub = g[g[col].astype(str) == cat]
        ax.scatter(
            sub.geometry.x, sub.geometry.y,
            s=s,
            color=colors[cat],
            edgecolor="black",
            linewidth=0.2,
            label=cat,
            transform=ccrs.PlateCarree(),
            zorder=3
        )

    gl = ax.gridlines(draw_labels=True, linewidth=0.3, linestyle="--")
    gl.top_labels = False
    gl.right_labels = False

    ax.set_title(title or f"GEV_all coloured by {col}")

    # Legend handling (CoastType can have loads)
    if n <= max_legend_items:
        ax.legend(title=col, loc="lower left")
    else:
        # Too many categories: show counts instead of an unreadable legend
        counts = g[col].astype(str).value_counts()
        txt = "\n".join([f"{k}: {v}" for k, v in counts.head(max_legend_items).items()])
        txt += f"\n… +{n - max_legend_items} more"
        ax.text(
            0.01, 0.01, txt,
            transform=ax.transAxes,
            fontsize=9,
            va="bottom",
            bbox=dict(facecolor="white", alpha=0.8, edgecolor="none")
        )

    plt.tight_layout()
    plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from matplotlib.cm import get_cmap

def plot_cartopy(
    gdf,
    col,
    kind="categorical",        # "categorical" | "continuous"
    title=None,
    extent=[-20, 15, 48, 65],
    s=28,
    max_legend_items=20,
    cmap_cont="viridis",
    robust=True
):
    g = gdf[gdf[col].notna()].copy()
    if len(g) == 0:
        raise ValueError(f"No non-null values found in column '{col}'.")

    fig = plt.figure(figsize=(12, 9))
    ax = plt.axes(projection=ccrs.PlateCarree())
    ax.set_extent(extent, crs=ccrs.PlateCarree())

    ax.add_feature(cfeature.LAND, facecolor="lightgray", zorder=0)
    ax.add_feature(cfeature.COASTLINE, linewidth=0.6, zorder=1)
    ax.add_feature(cfeature.BORDERS, linewidth=0.3, zorder=1)

    # ---------------------------
    # CATEGORICAL
    # ---------------------------
    if kind == "categorical":
        categories = sorted(g[col].astype(str).unique())
        n = len(categories)

        cmap = get_cmap("tab20" if n <= 20 else "tab20b" if n <= 40 else "hsv")
        colors = {cat: cmap(i / max(1, n - 1)) for i, cat in enumerate(categories)}

        for cat in categories:
            sub = g[g[col].astype(str) == cat]
            ax.scatter(
                sub.geometry.x, sub.geometry.y,
                s=s,
                color=colors[cat],
                edgecolor="black",
                linewidth=0.2,
                label=cat,
                transform=ccrs.PlateCarree(),
                zorder=3
            )

        if n <= max_legend_items:
            ax.legend(title=col, loc="lower left")
        else:
            counts = g[col].astype(str).value_counts()
            txt = "\n".join([f"{k}: {v}" for k, v in counts.head(max_legend_items).items()])
            txt += f"\n… +{n - max_legend_items} more"
            ax.text(
                0.01, 0.01, txt,
                transform=ax.transAxes,
                fontsize=9,
                va="bottom",
                bbox=dict(facecolor="white", alpha=0.8, edgecolor="none")
            )

    # ---------------------------
    # CONTINUOUS
    # ---------------------------
    elif kind == "continuous":
        values = g[col].astype(float)

        if robust:
            vmin, vmax = np.nanpercentile(values, [2, 98])
        else:
            vmin, vmax = np.nanmin(values), np.nanmax(values)

        sc = ax.scatter(
            g.geometry.x, g.geometry.y,
            c=values,
            s=s,
            cmap=cmap_cont,
            vmin=vmin,
            vmax=vmax,
            edgecolor="black",
            linewidth=0.2,
            transform=ccrs.PlateCarree(),
            zorder=3
        )

        cb = plt.colorbar(sc, ax=ax, shrink=0.75)
        cb.set_label(col)

    else:
        raise ValueError("kind must be 'categorical' or 'continuous'")

    gl = ax.gridlines(draw_labels=True, linewidth=0.3, linestyle="--")
    gl.top_labels = False
    gl.right_labels = False

    ax.set_title(title or f"GEV_all coloured by {col}")
    plt.tight_layout()
    plt.show()

# %%
plot_cartopy(
    GEV_all,
    col="CVI_Category",
    title="GEV points coloured by nearest CVI_Category",
    s=34
)
# Out:
# /var/folders/2b/rpgq1g5d5qz2nhbpj5s4jnrc0000gq/T/ipykernel_56348/2370617341.py:38: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = get_cmap("tab20" if n <= 20 else "tab20b" if n <= 40 else "hsv")

# %%
plot_cartopy(
    GEV_all,
    col="CoastType",
    title="GEV points coloured by nearest CoastType",
    s=22,
    max_legend_items=20
)
# Out:
# /var/folders/2b/rpgq1g5d5qz2nhbpj5s4jnrc0000gq/T/ipykernel_56348/2370617341.py:38: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = get_cmap("tab20" if n <= 20 else "tab20b" if n <= 40 else "hsv")

# %%
plot_cartopy(
    GEV_all,
    col="Morpho",
    title="GEV points coloured by nearest Morpho class",
    s=26,
    max_legend_items=20
)
# Out:
# /var/folders/2b/rpgq1g5d5qz2nhbpj5s4jnrc0000gq/T/ipykernel_56348/2370617341.py:38: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = get_cmap("tab20" if n <= 20 else "tab20b" if n <= 40 else "hsv")

# %%
import numpy as np
import rasterio
from rasterio.windows import from_bounds

def add_raster_mean_box(
    points_gdf,
    raster_path,
    out_col,
    half_size_deg=0.1,
    nodata_absurd=1e10
):
    """
    Adds column `out_col` to points_gdf: mean raster value within a box
    (lon±half_size_deg, lat±half_size_deg) around each point.

    Assumes points are EPSG:4326 if raster is EPSG:4326. If raster CRS differs,
    points are reprojected to raster CRS and the half-size is interpreted in raster units.
    """
    with rasterio.open(raster_path) as src:
        # Reproject points to raster CRS (required)
        if points_gdf.crs != src.crs:
            pts = points_gdf.to_crs(src.crs)
        else:
            pts = points_gdf

        nodata = src.nodata
        results = np.full(len(pts), np.nan, dtype=float)

        # Iterate points (fast enough for a few thousand points)
        for i, geom in enumerate(pts.geometry):
            if geom is None or geom.is_empty:
                continue

            x, y = geom.x, geom.y

            # Define bounds of the box
            left   = x - half_size_deg
            right  = x + half_size_deg
            bottom = y - half_size_deg
            top    = y + half_size_deg

            # Build window in raster pixel coordinates
            try:
                win = from_bounds(left, bottom, right, top, transform=src.transform)
            except Exception:
                continue

            # Read raster window
            arr = src.read(1, window=win, masked=False)

            # Convert to float + mask nodata/absurd
            arr = arr.astype(float)

            if nodata is not None:
                arr[arr == nodata] = np.nan

            arr[np.abs(arr) > nodata_absurd] = np.nan

            # Compute mean
            if np.isfinite(arr).any():
                results[i] = np.nanmean(arr)

        # Attach back to original gdf (aligned by row order)
        points_gdf[out_col] = results

    return points_gdf

# %%
import numpy as np
import rasterio
from rasterio.windows import from_bounds

def add_raster_mean_box(
    points_gdf,
    raster_path,
    out_col,
    half_size_deg=0.1,
    nodata_absurd=1e10   # <-- ONLY threshold used
):
    with rasterio.open(raster_path) as src:
        pts = points_gdf.to_crs(src.crs) if points_gdf.crs != src.crs else points_gdf

        nodata = src.nodata
        results = np.full(len(pts), np.nan, dtype=float)

        for i, geom in enumerate(pts.geometry):
            if geom is None or geom.is_empty:
                continue

            x, y = geom.x, geom.y
            left, right = x - half_size_deg, x + half_size_deg
            bottom, top = y - half_size_deg, y + half_size_deg

            try:
                win = from_bounds(left, bottom, right, top, transform=src.transform)
            except Exception:
                continue

            arr = src.read(1, window=win, masked=False).astype(float)

            # mask raster nodata
            if nodata is not None:
                arr[arr == nodata] = np.nan

            # ✅ mask absurd fill values ONLY
            arr[np.abs(arr) > nodata_absurd] = np.nan

            if np.isfinite(arr).any():
                results[i] = np.nanmean(arr)

        points_gdf[out_col] = results

    return points_gdf

# %%
GEV_all = add_raster_mean_box(
    GEV_all,
    wave_raster_path_NC,
    out_col="wave_nc_mean_0p1deg",
    half_size_deg=0.1
)

GEV_all = add_raster_mean_box(
    GEV_all,
    wave_raster_path_atlantic,
    out_col="wave_atl_mean_0p1deg",
    half_size_deg=0.1
)

# %%
import rasterio
with rasterio.open(current_raster_path) as src:
    print("Raster CRS:", src.crs)
# Out:
# Raster CRS: None

# %%
import numpy as np
import rasterio
from rasterio.windows import from_bounds

def add_raster_mean_box(
    points_gdf,
    raster_path,
    out_col,
    half_size_deg=0.1,
    nodata_absurd=1e5,
    raster_epsg_if_missing=4326  # ✅ fallback
):
    with rasterio.open(raster_path) as src:
        raster_crs = src.crs
        if raster_crs is None:
            raster_crs = f"EPSG:{raster_epsg_if_missing}"

        pts = points_gdf.to_crs(raster_crs) if points_gdf.crs != raster_crs else points_gdf

        nodata = src.nodata
        results = np.full(len(pts), np.nan, dtype=float)

        for i, geom in enumerate(pts.geometry):
            if geom is None or geom.is_empty:
                continue

            x, y = geom.x, geom.y
            left, right = x - half_size_deg, x + half_size_deg
            bottom, top = y - half_size_deg, y + half_size_deg

            try:
                win = from_bounds(left, bottom, right, top, transform=src.transform)
            except Exception:
                continue

            arr = src.read(1, window=win, masked=False).astype(float)

            if nodata is not None:
                arr[arr == nodata] = np.nan

            arr[np.abs(arr) > nodata_absurd] = np.nan

            if np.isfinite(arr).any():
                results[i] = np.nanmean(arr)

        points_gdf[out_col] = results

    return points_gdf

# %%
GEV_all = add_raster_mean_box(GEV_all, current_raster_path, "current_mean_0p1deg", half_size_deg=0.1)
GEV_all = add_raster_mean_box(GEV_all, current_raster_path, "current_mean_1deg",   half_size_deg=1.0)

# %%
GEV_all = add_raster_mean_box(
    GEV_all,
    current_raster_path,
    out_col="current_mean_0p1deg",
    half_size_deg=0.1
)

GEV_all = add_raster_mean_box(
    GEV_all,
    current_raster_path,
    out_col="current_mean_1deg",
    half_size_deg=1.0
)

# %%
plot_cartopy(
    GEV_all,
    kind='continuous',
    col="current_mean_1deg",
    title="GEV points coloured by nearest CoastType",
    s=22,
    max_legend_items=20
)

# %%
plot_cartopy(
    GEV_all,
    kind="continuous",
    col="current_mean_0p1deg",
    title="GEV points coloured by nearest CoastType",
    s=22,
    max_legend_items=0
)

# %%
import geopandas as gpd

gdb_path = "/Users/lb962/Downloads/HydroRIVERS_v10_eu.gdb/HydroRIVERS_v10_eu.gdb"
print(gpd.list_layers(gdb_path))  # see available layers

rivers = gpd.read_file(gdb_path)  # or layer="HydroRIVERS_v10_eu" etc.
print(rivers.columns)
# Out:
#                  name    geometry_type
# 0  HydroRIVERS_v10_eu  MultiLineString
# Index(['HYRIV_ID', 'NEXT_DOWN', 'MAIN_RIV', 'LENGTH_KM', 'DIST_DN_KM',
#        'DIST_UP_KM', 'CATCH_SKM', 'UPLAND_SKM', 'ENDORHEIC', 'DIS_AV_CMS',
#        'ORD_STRA', 'ORD_CLAS', 'ORD_FLOW', 'HYBAS_L12', 'Shape_Length',
#        'geometry'],
#       dtype='object')

# %%
outlets = rivers[rivers["NEXT_DOWN"] == 0].copy()

if "ENDORHEIC" in outlets.columns:
    outlets = outlets[outlets["ENDORHEIC"] == 0].copy()  # keep ocean outlets only

# %%
from shapely.geometry import Point

def downstream_point(line):
    coords = list(line.coords)
    return Point(coords[-1])

# If MultiLineString, take the longest part (simple heuristic)
def downstream_point_any(geom):
    if geom.geom_type == "LineString":
        return downstream_point(geom)
    if geom.geom_type == "MultiLineString":
        part = max(list(geom.geoms), key=lambda g: g.length)
        return downstream_point(part)
    return None

outlets = outlets[outlets.geometry.notna() & ~outlets.geometry.is_empty].copy()
outlets["geometry"] = outlets.geometry.apply(downstream_point_any)
outlets = outlets[outlets.geometry.notna()].copy()
outlets = outlets.set_geometry("geometry")

# %%
PROJECTED_EPSG = 3035  # good for Europe; use 3857 if your domain is broader

GEV_proj = GEV_all.to_crs(epsg=PROJECTED_EPSG)
outlets_proj = outlets.to_crs(epsg=PROJECTED_EPSG)

GEV_with_outlet = gpd.sjoin_nearest(
    GEV_proj,
    outlets_proj[["HYRIV_ID", "geometry"]],
    how="left",
    distance_col="dist_to_river_outlet_m"
).drop(columns=["index_right"], errors="ignore")

GEV_with_outlet = GEV_with_outlet.to_crs(epsg=4326)

# %%
rivers_proj = rivers.to_crs(epsg=PROJECTED_EPSG)
GEV_proj = GEV_all.to_crs(epsg=PROJECTED_EPSG)

GEV_on_river = gpd.sjoin_nearest(
    GEV_proj,
    rivers_proj[["HYRIV_ID", "DIST_DN_KM", "geometry"]],
    how="left",
    distance_col="dist_to_nearest_reach_m"
).drop(columns=["index_right"], errors="ignore")

GEV_on_river["downstream_to_outlet_km"] = GEV_on_river["DIST_DN_KM"]
GEV_on_river = GEV_on_river.to_crs(epsg=4326)

# %%
plot_cartopy(
    GEV_with_outlet,
    kind="continuous",
    col="dist_to_river_outlet_m",
    title="Distance to Coastal River Outlet (Euclidean, metres)",
)

# %%
GEV_with_outlet["log_dist_to_outlet"] = np.log10(
    GEV_with_outlet["dist_to_river_outlet_m"] + 1
)

plot_cartopy(
    GEV_with_outlet,
    kind="continuous",
    col="log_dist_to_outlet",
    title="Distance to Coastal River Outlet (Euclidean, metres)",
)

# %%
plot_cartopy(
    GEV_on_river,
    kind="continuous",
    col="downstream_to_outlet_km",
    title="Distance to Coastal River Outlet (Euclidean, metres)",
)

# %%
# GEV_with_outlet came from joining OUTLETS onto GEV_all (left = GEV_all)
cols_to_add = ["dist_to_river_outlet_m"]
if "downstream_to_outlet_km" in GEV_with_outlet.columns:
    cols_to_add.append("downstream_to_outlet_km")

GEV_all = GEV_all.join(GEV_with_outlet[cols_to_add])

# %%
import numpy as np
import geopandas as gpd

# ---- settings ----
PROJECTED_EPSG = 3035
MAX_DIST_M = 10_000  # 10 km

# ---- ensure stable ID (recommended once) ----
GEV_all = GEV_all.copy()
if "GEV_ID" not in GEV_all.columns:
    GEV_all["GEV_ID"] = np.arange(len(GEV_all))

# ---- project to metres for distance computations ----
GEV_proj = GEV_all.to_crs(epsg=PROJECTED_EPSG)
rivers_proj = rivers.to_crs(epsg=PROJECTED_EPSG)

# ---- avoid sjoin column collisions from previous joins ----
GEV_proj = GEV_proj.drop(columns=["index_right", "index_left"], errors="ignore")
rivers_proj = rivers_proj.drop(columns=["index_right", "index_left"], errors="ignore")

# ---- nearest river reach join ----
nearest_riv = gpd.sjoin_nearest(
    GEV_proj,
    rivers_proj[["HYRIV_ID", "DIS_AV_CMS", "CATCH_SKM", "DIST_DN_KM", "geometry"]],
    how="left",
    distance_col="dist_to_nearest_river_m"
).drop(columns=["index_right"], errors="ignore")

# ---- apply 10 km condition ----
within10 = nearest_riv["dist_to_nearest_river_m"] <= MAX_DIST_M

# Catchment area only if within 10 km
nearest_riv["nearest_CATCH_SKM_10km"] = np.where(within10, nearest_riv["CATCH_SKM"], np.nan)

# (Optional) keep discharge too (useful for RiverIndex)
nearest_riv["nearest_DIS_AV_CMS_10km"] = np.where(within10, nearest_riv["DIS_AV_CMS"], np.nan)

# ---- RiverIndex definition ----
# Preferred denominator: your previously computed Euclidean distance to coastal outlet (in metres)
# Fallback: use DIST_DN_KM (along-network km) if dist_to_river_outlet_m isn't in your table yet
if "dist_to_river_outlet_m" in nearest_riv.columns:
    denom_km = (nearest_riv["dist_to_river_outlet_m"] / 1000.0) + 1.0
else:
    denom_km = nearest_riv["DIST_DN_KM"] + 1.0

nearest_riv["river_index_10km"] = np.where(
    within10,
    np.log1p(nearest_riv["DIS_AV_CMS"]) / denom_km,
    np.nan
)

# ---- merge back into GEV_all by GEV_ID ----
cols_back = [
    "GEV_ID",
    "HYRIV_ID",
    "dist_to_nearest_river_m",
    "nearest_CATCH_SKM_10km",
    "nearest_DIS_AV_CMS_10km",
    "river_index_10km"
]

GEV_all = GEV_all.merge(
    nearest_riv[cols_back].drop_duplicates("GEV_ID"),
    on="GEV_ID",
    how="left",
    suffixes=("", "_riv")
)

# %%
plot_cartopy(
    GEV_all,
    kind="continuous",
    col="river_index_10km",
    title="River Index",
)

# %%
GEV_all["coastal_type"]= result2.coastal_type

# %%
GEV_all.to_csv("/Users/lb962/Documents/GitHub/ESL_stats/notebooks/C_KDE/static_contributers_test_df.csv")
