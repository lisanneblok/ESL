# %%
import os
import xarray as xr
import pandas as pd

# Load and concatenate datasets along a new dimension if needed
#ds = xr.open_mfdataset(nc_files, combine='by_coords')  # or combine='nested' with concat_dim='time' if needed
ds = xr.open_dataset("/Users/lb962/Documents/GitHub/ESL/data/processed/filtered_GESLA_sea_level.nc")
lat = ds['latitude'].values
lon = ds['longitude'].values

# If lat/lon are scalars or arrays, pair them
latlon_pairs = list(zip(lat.flatten(), lon.flatten()))
unique_latlon = list(set(latlon_pairs))  # remove duplicates

# %%
select_ds = ds.sel(station=2)

# %%
select_ds.sea_level.plot()

# %%
from utide import solve, reconstruct
import numpy as np

# Extract time in hours since start
#t = (select_ds.date_time.values - select_ds.date_time.values[0]) / np.timedelta64(1, 'D')  # days
t = select_ds["date_time"]
# Sea level values
y = select_ds['sea_level'].values

latitude = select_ds.latitude.item()

# Mask for valid (non-NaN) values
mask = ~np.isnan(y)

# Filter both time and data
t_clean = t[mask]
y_clean = y[mask]

# Now run UTide
from utide import solve, reconstruct
coef = solve(t_clean, y_clean, lat=latitude, method='ols', conf_int='linear')

# To reconstruct at original times (including NaNs), you can later do:
reconstructed = reconstruct(t, coef)  # UTide can still interpolate at full t

# Add back to dataset
select_ds['tide'] = ('time', reconstructed.h)
select_ds['residual'] = ('time', y -reconstructed.h)  # this is the "detided" signal

# %%
select_ds['tide'].plot()
# Out:
# solve: matrix prep ... solution ... done.
# prep/calcs ... done.

# %%
select_ds['residual'].plot()

# %%
from utide import solve, reconstruct
import numpy as np

# Extract time in hours since start
#t = (select_ds.date_time.values - select_ds.date_time.values[0]) / np.timedelta64(1, 'D')  # days
t = select_ds["date_time"]
# Sea level values
y = select_ds['sea_level'].values

latitude = select_ds.latitude.item()

# Mask for valid (non-NaN) values
mask = ~np.isnan(y)

# Filter both time and data
t_clean = t[mask]
y_clean = y[mask]

# Now run UTide
from utide import solve, reconstruct
coef = solve(t_clean, y_clean, lat=latitude, method='ols', conf_int='none')

# To reconstruct at original times (including NaNs), you can later do:
reconstructed = reconstruct(t, coef)  # UTide can still interpolate at full t

# Add back to dataset
select_ds['tide'] = ('time', reconstructed.h)
select_ds['residual'] = ('time', y -reconstructed.h)  # this is the "detided" signal
# Out:
# solve: matrix prep ... solution ... done.
# prep/calcs ... done.

# %%
select_ds['residual'].plot()

# %%
select_ds['tide'].plot()

# %%
from utide import solve, reconstruct

# %%
from utide import solve

coef = solve(
    time,
    time_series_u,
    time_series_v,
    lat=30,
    nodal=False,
    trend=False,
    method="ols",
    conf_int="linear",
    Rayleigh_min=0.95,
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 4
#       1 from utide import solve
#       3 coef = solve(
# ----> 4     time,
#       5     time_series_u,
#       6     time_series_v,
#       7     lat=30,
#       8     nodal=False,
#       9     trend=False,
#      10     method="ols",
#      11     conf_int="linear",
#      12     Rayleigh_min=0.95,
#      13 )
#
# NameError: name 'time' is not defined

# %%
# !python3 -m pip install pyTMD
# Out:
# Collecting pyTMD
#   Downloading pytmd-2.2.6-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: lxml in /Users/lb962/miniconda3/envs/ESL/lib/python3.12/site-packages (from pyTMD) (5.3.1)
# Requirement already satisfied: netCDF4 in /Users/lb962/miniconda3/envs/ESL/lib/python3.12/site-packages (from pyTMD) (1.6.5)
# Requirement already satisfied: numpy in /Users/lb962/miniconda3/envs/ESL/lib/python3.12/site-packages (from pyTMD) (1.26.4)
# Requirement already satisfied: pyproj in /Users/lb962/miniconda3/envs/ESL/lib/python3.12/site-packages (from pyTMD) (3.6.1)
# Requirement already satisfied: python-dateutil in /Users/lb962/miniconda3/envs/ESL/lib/python3.12/site-packages (from pyTMD) (2.8.2)
# Requirement already satisfied: scipy>=1.10.1 in /Users/lb962/miniconda3/envs/ESL/lib/python3.12/site-packages (from pyTMD) (1.11.4)
# Collecting setuptools_scm (from pyTMD)
#   Downloading setuptools_scm-9.0.1-py3-none-any.whl.metadata (7.7 kB)
# Collecting timescale>=0.0.8 (from pyTMD)
#   Downloading timescale-0.0.9-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: cftime in /Users/lb962/miniconda3/envs/ESL/lib/python3.12/site-packages (from netCDF4->pyTMD) (1.6.3)
# Requirement already satisfied: certifi in /Users/lb962/miniconda3/envs/ESL/lib/python3.12/site-packages (from netCDF4->pyTMD) (2024.2.2)
# Requirement already satisfied: six>=1.5 in /Users/lb962/miniconda3/envs/ESL/lib/python3.12/site-packages (from python-dateutil->pyTMD) (1.16.0)
# Requirement already satisfied: packaging>=20 in /Users/lb962/miniconda3/envs/ESL/lib/python3.12/site-packages (from setuptools_scm->pyTMD) (23.2)
# Requirement already satisfied: setuptools in /Users/lb962/miniconda3/envs/ESL/lib/python3.12/site-packages (from setuptools_scm->pyTMD) (68.0.0)
# Downloading pytmd-2.2.6-py3-none-any.whl (6.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 881.8 kB/s eta 0:00:0000:0100:01
# Downloading timescale-0.0.9-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 3.7 MB/s eta 0:00:00a 0:00:01
# Downloading setuptools_scm-9.0.1-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 kB 2.2 MB/s eta 0:00:00
# Installing collected packages: setuptools_scm, timescale, pyTMD
# Successfully installed pyTMD-2.2.6 setuptools_scm-9.0.1 timescale-0.0.9

# %%
import numpy as np
import datetime
from utide import solve, reconstruct

# %%
from pytides.tide import Tide
from pytides.constituent import constituents
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 from pytides.tide import Tide
#       2 from pytides.constituent import constituents
#       3 import pandas as pd
#
# File ~/miniconda3/envs/ESL/lib/python3.12/site-packages/pytides/__init__.py:3
#       1 # -*- coding: utf-8 -*-
# ----> 3 import tide
#       4 import astro
#       5 import constituent
#
# File ~/miniconda3/envs/ESL/lib/python3.12/site-packages/tide/tide.py:7
#       5 sys.path.insert(0, os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe()))))
#       6 import lib_paths
# ----> 7 from command_handler import CommandHandler
#       8 from config_command import ConfigCommand
#       9 from config_command_item import ConfigCommandItem
#
# File ~/miniconda3/envs/ESL/lib/python3.12/site-packages/tide/command_handler.py:3
#       1 import traceback
#       2 from singleton import singleton
# ----> 3 from config import Config
#       4 from config_command import ConfigCommand
#       5 from config_command_item import ConfigCommandItem
#
# File ~/miniconda3/envs/ESL/lib/python3.12/site-packages/tide/config.py:3
#       1 from singleton import singleton
#       2 from actionable_dict import ActionableDict
# ----> 3 from editor_wrapper import EditorWrapper
#       4 import config_source as Cs
#       5 from logging_decorator import logging
#
# File ~/miniconda3/envs/ESL/lib/python3.12/site-packages/tide/editor_wrapper.py:7
#       5 from os.path import isfile, join
#       6 from pathlib import Path
# ----> 7 from logging_decorator import logging
#       8 import path_helpers as Ph
#      10 @logging
#      11 class EditorWrapper(object):
#
# File ~/miniconda3/envs/ESL/lib/python3.12/site-packages/tide/logging_decorator.py:6
#       4 import json
#       5 import types
# ----> 6 import config_source as Cs
#       8 DEBUG_SETTINGS = Cs.CONFIG_OBJECT["settings"]["debugging"]
#       9 DEBUG_KEYS = DEBUG_SETTINGS.keys()
#
# File ~/miniconda3/envs/ESL/lib/python3.12/site-packages/tide/config_source.py:101
#      98             sys.path.insert(0, function_path)
#      99     return function_paths
# --> 101 FULL_CONFIG_LOCATION = __get_base_config_location()
#     103 CONFIG_LOCATION_ARRAY = __get_all_config_locations()
#     105 CONFIG_OBJECT = __get_all_configs()
#
# File ~/miniconda3/envs/ESL/lib/python3.12/site-packages/tide/config_source.py:44, in __get_base_config_location()
#      42 if location_file_path:
#      43     return location_file_path
# ---> 44 raise RuntimeError("error: unable to find a matching path for the config. please either set the environment variable TIDE_CONFIG_LOCATION or specify in the file config_location.yaml")
#
# RuntimeError: error: unable to find a matching path for the config. please either set the environment variable TIDE_CONFIG_LOCATION or specify in the file config_location.yaml

# %%
import os
import datetime as dt
import pandas as pd
import xarray as xr
import hatyan
hatyan.close('all')

# %%
# optionally set logging level/format (and stream to prevent red background)
import logging, sys
logging.basicConfig(level="INFO", format='%(message)s', stream=sys.stdout)

# %%
# defining a list of the components to be analysed ()'year' contains 94 components and the mean H0)
const_list = hatyan.get_const_list_hatyan('year')

# %%
# reading and editing time series (Cuxhaven dataset from UHSLC database)
# results in a pandas DataFrame a 'values' column (water level in meters) and a pd.DatetimeIndex as index
file_data_meas = 'http://uhslc.soest.hawaii.edu:80/opendap/rqds/global/hourly/h825a.nc'
times_pred = slice("2017-01-01", "2018-12-31", "10min")
ts_data = xr.open_dataset(file_data_meas)
ts_data_sel = ts_data.sea_level.isel(record_id=0).sel(time=slice(times_pred.start,times_pred.stop))
# correct from mm to meters and for 5m offset
ts_data_sel = (ts_data_sel/1000-5)
ts_meas = pd.DataFrame({'values':ts_data_sel.to_series()})
ts_meas.attrs['eenheid'] = 'm' # required for hatyan.plot_HWLW_validatestats()

# %%
# inspect ts_meas
print(ts_meas)
# Out:
#                             values
# time
# 2017-01-01 00:00:00.000000    1.56
# 2017-01-01 01:00:00.028800    1.85
# 2017-01-01 01:59:59.971200    1.95
# 2017-01-01 03:00:00.000000    1.68
# 2017-01-01 04:00:00.028800    1.02
# ...                            ...
# 2018-12-31 19:00:00.028800    1.37
# 2018-12-31 19:59:59.971200    1.36
# 2018-12-31 21:00:00.000000    1.02
# 2018-12-31 22:00:00.028800    0.49
# 2018-12-31 22:59:59.971200   -0.04
#
# [17520 rows x 1 columns]

# %%
# tidal analysis and plotting of results 
comp_mean, comp_allperiods = hatyan.analysis(ts=ts_meas, const_list=const_list, 
                                               nodalfactors=True, return_allperiods=True,
                                               fu_alltimes=True, analysis_perperiod='Y')
fig,(ax1,ax2) = hatyan.plot_components(comp=comp_mean, comp_allperiods=comp_allperiods)
# fig.savefig('components.png')
# Out:
# ANALYSIS initializing
# nodalfactors         = True
# fu_alltimes          = True
# xfac                 = False
# source               = schureman
# return_allperiods    = True
# analysis_perperiod   = Y
# max_matrix_condition = 12
#
# n components analyzed  = 95
# analysis_perperiod=Y, separate periods are automatically determined from timeseries
# analyzing 2017 of sequence ['2017', '2018']
# #timesteps    = 8760
# tstart        = 2017-01-01 00:00:00
# tstop         = 2017-12-31 22:59:59
# timestep      = None
# percentage_nan in values_meas_sel: 0.00%
# nodal factors (f and u) are calculated for all timesteps
# folding frequencies over Nyquist frequency, which is half of the dominant timestep (1.000008 hour), there are 2 unique timesteps)
# Rayleigh criterion OK (always>0.70, minimum is 1.00)
# Frequencies are far enough apart (always >0.000080, minimum is 0.000114)
# calculating xTx matrix
# condition of xTx matrix: 3.91
# matrix system solved, elapsed time: 0:00:00.023166
# analyzing 2018 of sequence ['2017', '2018']
# #timesteps    = 8760
# tstart        = 2018-01-01 00:00:00
# tstop         = 2018-12-31 22:59:59
# timestep      = None
# percentage_nan in values_meas_sel: 0.00%
# nodal factors (f and u) are calculated for all timesteps
# folding frequencies over Nyquist frequency, which is half of the dominant timestep (1.000008 hour), there are 2 unique timesteps)
# Rayleigh criterion OK (always>0.70, minimum is 1.00)
# Frequencies are far enough apart (always >0.000080, minimum is 0.000114)
# calculating xTx matrix
# condition of xTx matrix: 3.07
# matrix system solved, elapsed time: 0:00:00.067944
# vector averaging analysis results

# %%
from datetime import datetime
#from pytides.tide import Tide
import numpy as np
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[9], line 3
#       1 from datetime import datetime
#       2 #from pytides.tide import Tide
# ----> 3 import pytides
#       4 import numpy as np
#       5 import matplotlib.pyplot as plt
#
# File ~/miniconda3/envs/ESL/lib/python3.12/site-packages/pytides/__init__.py:3
#       1 # -*- coding: utf-8 -*-
# ----> 3 import tide
#       4 import astro
#       5 import constituent
#
# File ~/miniconda3/envs/ESL/lib/python3.12/site-packages/tide/tide.py:7
#       5 sys.path.insert(0, os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe()))))
#       6 import lib_paths
# ----> 7 from command_handler import CommandHandler
#       8 from config_command import ConfigCommand
#       9 from config_command_item import ConfigCommandItem
#
# File ~/miniconda3/envs/ESL/lib/python3.12/site-packages/tide/command_handler.py:3
#       1 import traceback
#       2 from singleton import singleton
# ----> 3 from config import Config
#       4 from config_command import ConfigCommand
#       5 from config_command_item import ConfigCommandItem
#
# File ~/miniconda3/envs/ESL/lib/python3.12/site-packages/tide/config.py:3
#       1 from singleton import singleton
#       2 from actionable_dict import ActionableDict
# ----> 3 from editor_wrapper import EditorWrapper
#       4 import config_source as Cs
#       5 from logging_decorator import logging
#
# File ~/miniconda3/envs/ESL/lib/python3.12/site-packages/tide/editor_wrapper.py:7
#       5 from os.path import isfile, join
#       6 from pathlib import Path
# ----> 7 from logging_decorator import logging
#       8 import path_helpers as Ph
#      10 @logging
#      11 class EditorWrapper(object):
#
# File ~/miniconda3/envs/ESL/lib/python3.12/site-packages/tide/logging_decorator.py:6
#       4 import json
#       5 import types
# ----> 6 import config_source as Cs
#       8 DEBUG_SETTINGS = Cs.CONFIG_OBJECT["settings"]["debugging"]
#       9 DEBUG_KEYS = DEBUG_SETTINGS.keys()
#
# File ~/miniconda3/envs/ESL/lib/python3.12/site-packages/tide/config_source.py:101
#      98             sys.path.insert(0, function_path)
#      99     return function_paths
# --> 101 FULL_CONFIG_LOCATION = __get_base_config_location()
#     103 CONFIG_LOCATION_ARRAY = __get_all_config_locations()
#     105 CONFIG_OBJECT = __get_all_configs()
#
# File ~/miniconda3/envs/ESL/lib/python3.12/site-packages/tide/config_source.py:44, in __get_base_config_location()
#      42 if location_file_path:
#      43     return location_file_path
# ---> 44 raise RuntimeError("error: unable to find a matching path for the config. please either set the environment variable TIDE_CONFIG_LOCATION or specify in the file config_location.yaml")
#
# RuntimeError: error: unable to find a matching path for the config. please either set the environment variable TIDE_CONFIG_LOCATION or specify in the file config_location.yaml
