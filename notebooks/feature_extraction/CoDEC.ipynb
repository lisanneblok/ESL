# %% [markdown]
# https://www.frontiersin.org/articles/10.3389/fmars.2020.00263/full

# %%
import cdsapi

c = cdsapi.Client()

c.retrieve(
    'sis-water-level-change-timeseries-cmip6',
    {
        'format': 'zip',
        'variable': 'tidal_elevation',
        'experiment': 'historical',
        'temporal_aggregation': '10_min',
        'year': [
            '1950', '1951', '1952',
            '1953', '1954', '1955',
            '1956', '1957',
        ],
        'month': [
            '01', '02', '03',
            '04', '05', '06',
            '07', '08', '09',
            '10', '11', '12',
        ],
    },
    'API_calls/CoDEC/tides1950-1958.zip')
# Out:
# 2024-02-09 10:32:43,939 INFO Welcome to the CDS
# 2024-02-09 10:32:43,940 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/sis-water-level-change-timeseries-cmip6
# 2024-02-09 10:32:44,271 INFO Request is completed
# 2024-02-09 10:32:44,271 INFO Downloading https://download-0002-clone.copernicus-climate.eu/cache-compute-0002/cache/data9/dataset-sis-water-level-change-timeseries-cmip6-b5943595-263b-4007-bf66-c4e4f26eff81.zip to API_calls/CoDEC/tides1950-1958.zip (19.7G)
# 2024-02-09 11:33:19,539 INFO Download rate 5.5M/s
# Result(content_length=21142687385,content_type=application/zip,location=https://download-0002-clone.copernicus-climate.eu/cache-compute-0002/cache/data9/dataset-sis-water-level-change-timeseries-cmip6-b5943595-263b-4007-bf66-c4e4f26eff81.zip)

# %%
c.retrieve(
    'sis-water-level-change-timeseries-cmip6',
    {
        'format': 'zip',
        'variable': 'tidal_elevation',
        'experiment': 'historical',
        'temporal_aggregation': '10_min',
        'year': [
            '1958', '1959', '1960',
            '1961', '1962', '1963',
            '1964', '1965',
        ],
        'month': [
            '01', '02', '03',
            '04', '05', '06',
            '07', '08', '09',
            '10', '11', '12',
        ],
    },
    'API_calls/CoDEC/tides1958-1965.zip')
# Out:
# 2024-02-09 11:37:18,879 INFO Welcome to the CDS
# 2024-02-09 11:37:18,879 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/sis-water-level-change-timeseries-cmip6
# 2024-02-09 11:37:18,970 INFO Request is queued
# 2024-02-09 11:37:20,031 INFO Request is running
# 2024-02-09 11:43:37,580 INFO Request is completed
# 2024-02-09 11:43:37,583 INFO Downloading https://download-0012-clone.copernicus-climate.eu/cache-compute-0012/cache/data0/dataset-sis-water-level-change-timeseries-cmip6-931e026a-f5d9-4bae-801b-e920f61ddee2.zip to API_calls/CoDEC/tides1958-1965.zip (19.6G)
# 2024-02-09 12:59:27,382 INFO Download rate 4.4M/s
# Result(content_length=21086842395,content_type=application/zip,location=https://download-0012-clone.copernicus-climate.eu/cache-compute-0012/cache/data0/dataset-sis-water-level-change-timeseries-cmip6-931e026a-f5d9-4bae-801b-e920f61ddee2.zip)

# %%
c.retrieve(
    'sis-water-level-change-timeseries-cmip6',
    {
        'format': 'zip',
        'variable': 'tidal_elevation',
        'experiment': 'historical',
        'temporal_aggregation': '10_min',
        'year': [
            '1966', '1967', '1968',
            '1969', '1970', '1971',
            '1972', '1973',
        ],
        'month': [
            '01', '02', '03',
            '04', '05', '06',
            '07', '08', '09',
            '10', '11', '12',
        ],
    },
    'API_calls/CoDEC/tides1966-1973.zip')
# Out:
# 2024-02-09 12:59:27,588 INFO Welcome to the CDS
# 2024-02-09 12:59:27,588 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/sis-water-level-change-timeseries-cmip6
# 2024-02-09 12:59:27,699 INFO Request is queued
# 2024-02-09 12:59:28,766 INFO Request is running
# 2024-02-09 13:05:46,280 INFO Request is completed
# 2024-02-09 13:05:46,283 INFO Downloading https://download-0012-clone.copernicus-climate.eu/cache-compute-0012/cache/data4/dataset-sis-water-level-change-timeseries-cmip6-d8e82d7c-77e2-440f-a12d-239ba380ac89.zip to API_calls/CoDEC/tides1966-1973.zip (19.2G)
# 2024-02-09 14:14:34,523 INFO Download rate 4.8M/s
# Result(content_length=20623130952,content_type=application/zip,location=https://download-0012-clone.copernicus-climate.eu/cache-compute-0012/cache/data4/dataset-sis-water-level-change-timeseries-cmip6-d8e82d7c-77e2-440f-a12d-239ba380ac89.zip)

# %%
c.retrieve(
    'sis-water-level-change-timeseries-cmip6',
    {
        'format': 'zip',
        'variable': 'tidal_elevation',
        'experiment': 'historical',
        'temporal_aggregation': '10_min',
        'year': [
            '1974', '1975', '1976',
            '1977', '1978', '1979',
            '1980', '1981',
        ],
        'month': [
            '01', '02', '03',
            '04', '05', '06',
            '07', '08', '09',
            '10', '11', '12',
        ],
    },
    'API_calls/CoDEC/tides1974-1981.zip')
# Out:
# 2024-02-09 14:59:32,318 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/sis-water-level-change-timeseries-cmip6
# 2024-02-09 14:59:32,631 INFO Downloading https://download-0019.copernicus-climate.eu/cache-compute-0019/cache/data7/dataset-sis-water-level-change-timeseries-cmip6-1c4329bf-24ef-4066-8528-4c14643f700d.zip to API_calls/CoDEC/tides1974-1981.zip (19.6G)
# 2024-02-09 16:08:26,702 INFO Download rate 4.8M/s
# Result(content_length=21004578871,content_type=application/zip,location=https://download-0019.copernicus-climate.eu/cache-compute-0019/cache/data7/dataset-sis-water-level-change-timeseries-cmip6-1c4329bf-24ef-4066-8528-4c14643f700d.zip)

# %%
c.retrieve(
    'sis-water-level-change-timeseries-cmip6',
    {
        'format': 'zip',
        'variable': 'tidal_elevation',
        'experiment': 'historical',
        'temporal_aggregation': '10_min',
        'year': [
            '1982', '1983', '1984',
            '1985', '1986', '1987',
            '1988', '1989',
        ],
        'month': [
            '01', '02', '03',
            '04', '05', '06',
            '07', '08', '09',
            '10', '11', '12',
        ],
    },
    'API_calls/CoDEC/tides1982-1989.zip')
# Out:
# 2024-02-09 22:05:49,583 INFO Welcome to the CDS
# 2024-02-09 22:05:49,584 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/sis-water-level-change-timeseries-cmip6
# 2024-02-09 22:05:49,838 INFO Downloading https://download-0012-clone.copernicus-climate.eu/cache-compute-0012/cache/data8/dataset-sis-water-level-change-timeseries-cmip6-c32beee9-a2d6-4a56-a490-6beb9bccc68c.zip to API_calls/CoDEC/tides1982-1989.zip (19.6G)
# 2024-02-09 23:25:10,235 INFO Download rate 4.2M/s
# Result(content_length=20998098916,content_type=application/zip,location=https://download-0012-clone.copernicus-climate.eu/cache-compute-0012/cache/data8/dataset-sis-water-level-change-timeseries-cmip6-c32beee9-a2d6-4a56-a490-6beb9bccc68c.zip)

# %%
c.retrieve(
    'sis-water-level-change-timeseries-cmip6',
    {
        'format': 'zip',
        'variable': 'tidal_elevation',
        'experiment': 'historical',
        'temporal_aggregation': '10_min',
        'year': [
            '1990', '1991', '1992',
            '1993', '1994', '1995',
            '1996', '1997',
        ],
        'month': [
            '01', '02', '03',
            '04', '05', '06',
            '07', '08', '09',
            '10', '11', '12',
        ],
    },
    'API_calls/CoDEC/tides1990-1997.zip')
# Out:
# 2024-02-09 23:25:10,488 INFO Welcome to the CDS
# 2024-02-09 23:25:10,489 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/sis-water-level-change-timeseries-cmip6
# 2024-02-09 23:25:10,592 INFO Request is queued
# 2024-02-09 23:25:11,655 INFO Request is running
# 2024-02-09 23:31:29,156 INFO Request is completed
# 2024-02-09 23:31:29,158 INFO Downloading https://download-0001-clone.copernicus-climate.eu/cache-compute-0001/cache/data4/dataset-sis-water-level-change-timeseries-cmip6-f842f6ac-8ccd-40a2-beef-bc0763c138c2.zip to API_calls/CoDEC/tides1990-1997.zip (19.5G)
# 2024-02-10 00:48:45,180 INFO Download rate 4.3M/s
# Result(content_length=20948697126,content_type=application/zip,location=https://download-0001-clone.copernicus-climate.eu/cache-compute-0001/cache/data4/dataset-sis-water-level-change-timeseries-cmip6-f842f6ac-8ccd-40a2-beef-bc0763c138c2.zip)

# %%
c.retrieve(
    'sis-water-level-change-timeseries-cmip6',
    {
        'format': 'zip',
        'variable': 'tidal_elevation',
        'experiment': 'historical',
        'temporal_aggregation': '10_min',
        'year': [
            '1998', '1999', '2000',
            '2001', '2002', '2003',
            '2004', '2005',
        ],
        'month': [
            '01', '02', '03',
            '04', '05', '06',
            '07', '08', '09',
            '10', '11', '12',
        ],
    },
    'API_calls/CoDEC/tides1998-2005.zip')
# Out:
# 2024-02-10 00:48:45,437 INFO Welcome to the CDS
# 2024-02-10 00:48:45,437 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/sis-water-level-change-timeseries-cmip6
# 2024-02-10 00:48:45,521 INFO Request is queued
# 2024-02-10 00:48:46,577 INFO Request is running
# 2024-02-10 00:48:48,144 WARNING HTTP error: [500 Internal Server Error]. Attempt 1 of 500.
# 2024-02-10 00:48:48,146 WARNING Retrying in 120 seconds
# 2024-02-10 00:50:48,150 INFO Retrying now...
# 2024-02-10 00:53:37,378 INFO Request is completed
# 2024-02-10 00:53:37,380 INFO Downloading https://download-0003-clone.copernicus-climate.eu/cache-compute-0003/cache/data4/dataset-sis-water-level-change-timeseries-cmip6-de4197a4-0498-48a3-844b-e66b8806b643.zip to API_calls/CoDEC/tides1998-2005.zip (19.5G)
# 2024-02-10 01:58:48,059 INFO Download rate 5.1M/s
# ...

# %%
c.retrieve(
    'sis-water-level-change-timeseries-cmip6',
    {
        'format': 'zip',
        'variable': 'tidal_elevation',
        'experiment': 'historical',
        'temporal_aggregation': '10_min',
        'year': [
            '2006', '2007', '2008',
            '2009', '2010', '2011',
            '2012', '2013',
        ],
        'month': [
            '01', '02', '03',
            '04', '05', '06',
            '07', '08', '09',
            '10', '11', '12',
        ],
    },
    'API_calls/CoDEC/tides2005-2013.zip')
# Out:
# 2024-02-10 01:58:48,432 INFO Welcome to the CDS
# 2024-02-10 01:58:48,434 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/sis-water-level-change-timeseries-cmip6
# 2024-02-10 01:58:48,522 INFO Request is queued
# 2024-02-10 01:58:49,581 INFO Request is running
# 2024-02-10 02:05:07,204 INFO Request is completed
# 2024-02-10 02:05:07,206 INFO Downloading https://download-0011-clone.copernicus-climate.eu/cache-compute-0011/cache/data7/dataset-sis-water-level-change-timeseries-cmip6-725d241c-48cc-4c3a-a79c-db1ff87185d1.zip to API_calls/CoDEC/tides2005-2013.zip (19.5G)
# 2024-02-10 03:11:24,555 INFO Download rate 5M/s
# Result(content_length=20989460903,content_type=application/zip,location=https://download-0011-clone.copernicus-climate.eu/cache-compute-0011/cache/data7/dataset-sis-water-level-change-timeseries-cmip6-725d241c-48cc-4c3a-a79c-db1ff87185d1.zip)

# %%
c.retrieve(
    'sis-water-level-change-timeseries-cmip6',
    {
        'format': 'zip',
        'variable': 'tidal_elevation',
        'experiment': 'historical',
        'temporal_aggregation': '10_min',
        'year': '2014',
        'month': [
            '01', '02', '03',
            '04', '05', '06',
            '07', '08', '09',
            '10', '11', '12',
        ],
    },
    'API_calls/CoDEC/tides2014zip')
# Out:
# 2024-02-10 03:11:24,754 INFO Welcome to the CDS
# 2024-02-10 03:11:24,755 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/sis-water-level-change-timeseries-cmip6
# 2024-02-10 03:11:24,930 INFO Request is queued
# 2024-02-10 03:11:25,993 INFO Request is running
# 2024-02-10 03:12:14,659 INFO Request is completed
# 2024-02-10 03:12:14,661 INFO Downloading https://download-0007-clone.copernicus-climate.eu/cache-compute-0007/cache/data0/dataset-sis-water-level-change-timeseries-cmip6-8c9b61f3-8795-4f73-a5fc-713b2e79689d.zip to API_calls/CoDEC/tides2014zip (2.4G)
# 2024-02-10 03:19:58,884 INFO Download rate 5.4M/s
# Result(content_length=2619710825,content_type=application/zip,location=https://download-0007-clone.copernicus-climate.eu/cache-compute-0007/cache/data0/dataset-sis-water-level-change-timeseries-cmip6-8c9b61f3-8795-4f73-a5fc-713b2e79689d.zip)

# %% [markdown]
# ## merge files

# %% [markdown]
# ## Select spatial range

# %%
import geopandas as gpd
from shapely.geometry import LineString

# Load coastline shapefile
coastline = gpd.read_file('/Users/lb962/Downloads/ESL/GESLA/data/Europe_coastline_shapefile (1)/Europe_coastline.shp')

# Define the projection
crs_etrs89 = "EPSG:3035"
crs_wgs84 = "EPSG:4326"

# Transform the coastline GeoDataFrame to longitude and latitude
coastline.to_crs(crs_wgs84, inplace=True)

# Define the longitude and latitude range for Europe
lon_min, lon_max = -11.5, 15.0  # Longitude range for Europe
lat_min, lat_max = 48, 65.0   # Latitude range for Europe

# Filter coastline points within the specified longitude and latitude range
coastline = coastline.cx[lon_min:lon_max, lat_min:lat_max]

# Define the interpolation interval range (in meters)
min_interval = 0.01  # Minimum interpolation interval
max_interval = 0.1  # Maximum interpolation interval

# Function to calculate adaptive interpolation interval based on segment length or curvature
def adaptive_interval(segment):
    segment_length = segment.length
    # Calculate curvature (ratio of segment length to chord length)
    chord_length = segment.distance(LineString([segment.coords[0], segment.coords[-1]]))
    curvature = segment_length / chord_length if chord_length != 0 else 0
    # Define a function to map curvature to interpolation interval within the specified range
    # Here, we use a simple linear mapping, but you can adjust this as needed
    mapped_interval = min_interval + (max_interval - min_interval) * (1 - curvature)
    # Ensure the interval is within the specified range
    return max(min(mapped_interval, max_interval), min_interval)

# Function to interpolate points along a line segment with adaptive interval
def interpolate_segment_adaptive(segment):
    # Calculate the adaptive interpolation interval for the segment
    interval = adaptive_interval(segment)
    # Calculate the number of interpolation points for the segment
    num_points = int(segment.length / interval) + 1
    # Interpolate points along the segment at adaptive intervals
    interpolated_points = [segment.interpolate(i * interval) for i in range(num_points)]
    return interpolated_points

# Interpolate points along each line segment of the MULTILINESTRING using adaptive interval
coastline_points_adaptive = []
for line in coastline.geometry:
    if line.geom_type == 'LineString':
        # If the geometry is a LineString, interpolate points along it
        coastline_points_adaptive.extend(interpolate_segment_adaptive(line))
    elif line.geom_type == 'MultiLineString':
        # If the geometry is a MultiLineString, iterate over its components and interpolate points along each segment
        for segment in line.geoms:
            coastline_points_adaptive.extend(interpolate_segment_adaptive(segment))

# Convert the coastline points to a GeoSeries
coastline_points = gpd.GeoSeries(coastline_points_adaptive)

# Filter the GeoSeries for points within the specified bounding box
coastline_points = coastline_points.cx[lon_min:lon_max, lat_min:lat_max]

# %%
import matplotlib.pyplot as plt


# Plot coastline points
plt.plot(coastline_points.x, coastline_points.y, 'r.', label='Coastline Points')

# Set labels and title
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Coastline Points')
plt.legend()

# Show the plot
plt.show()

# %%
import xarray as xr
import numpy as np
def process_file(input_file, coastline_points):
    # Open the NetCDF file using xarray
    ds = xr.open_dataset(input_file)

    # Rename station_y_coordinate to latitude and station_x_coordinate to longitude
    ds = ds.rename({'station_y_coordinate': 'latitude', 'station_x_coordinate': 'longitude'})

    # Extract longitude and latitude coordinates
    lon_values = ds['longitude'].values
    lat_values = ds['latitude'].values

    # Define the longitude and latitude range for Europe
    #lon_min, lon_max = -11.5, 35.0  # Longitude range for Europe
    #lat_min, lat_max = 29.5, 71.0   # Latitude range for Europe

    # Define the longitude and latitude range for Europe
    lon_min, lon_max = -11.5, 15.0  # Longitude range for Europe
    lat_min, lat_max = 48, 65.0   # Latitude range for Europe

    # Boolean indexing to select the desired range
    selected_indices = (lon_values >= lon_min) & (lon_values <= lon_max) & (lat_values >= lat_min) & (lat_values <= lat_max)
    selected_data = ds.isel(stations=selected_indices)

    # Extract longitude and latitude coordinates for selected data
    #lon_selected = selected_data['longitude'].values
    #lat_selected = selected_data['latitude'].values
    
    # Create arrays for longitude and latitude coordinates of coastline points
    coastline_lon = coastline_points.x.values
    coastline_lat = coastline_points.y.values

    # Get longitude and latitude values from the xarray dataset
    lon_values = selected_data['longitude'].values
    lat_values = selected_data['latitude'].values

    # Repeat coastline coordinates to match the shape of lon_values and lat_values
    coastline_lon_rep = np.repeat(coastline_lon[:, np.newaxis], len(lon_values), axis=1)
    coastline_lat_rep = np.repeat(coastline_lat[:, np.newaxis], len(lat_values), axis=1)

    print(coastline_lon_rep.shape)
    print(lon_values.shape)
    # Calculate distances between each point in the dataset and each coastline point
    distances = np.sqrt((lon_values - coastline_lon_rep)**2 + (lat_values - coastline_lat_rep)**2)

    # Find the minimum distance for each point in the dataset
    min_distances = np.min(distances, axis=0)

    # Define a threshold distance within which points are considered close to the coastline
    threshold_distance = 0.05  # Adjust as needed 0.05

    # Create a mask to select points close to the coastline
    coastline_mask = min_distances < threshold_distance

    # Use the mask to select coastline points in the original dataset
    coastline_data = selected_data.isel(stations=coastline_mask)
    #ds_hourly = coastline_data.resample(time='1H').mean()
    return coastline_data

# %%
# Define the folder containing the input files
input_file = "/Users/lb962/Downloads/ESL/GESLA/notebooks/feature_extraction/API_calls/CoDEC/tides2014/historical_tide_2014_01_v1.nc"

# %%
sel_data = process_file(input_file, coastline_points)
# Out:
# (28997, 5450)
# (5450,)

# %%
hallo = sel_data.to_dataframe()

# %%
sel_data
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 4464, stations: 2622)
# Coordinates:
#     longitude  (stations) float64 -5.076 -5.12 -2.161 ... 10.53 -3.025 -3.289
#     latitude   (stations) float64 48.45 48.46 49.27 49.27 ... 64.8 58.94 56.05
#   * time       (time) datetime64[ns] 2014-01-01 ... 2014-01-31T23:50:00
#   * stations   (stations) uint16 696 697 698 699 700 ... 41828 41950 43200 43390
# Data variables:
#     tide       (time, stations) float32 ...
# Attributes: (12/35)
#     Conventions:                   CF-1.6
#     featureType:                   timeSeries
#     id:                            GTSMv3_tides
#     naming_authority:              https://deltares.nl/en
#     Metadata_Conventions:          Unidata Dataset Discovery v1.0
#     title:                         10-minute timeseries of tide levels
#     ...                            ...
#     time_coverage_start:           2014-01-01 00:00:00
#     time_coverage_end:             2014-01-31 23:50:00
#     experiment:
# ...

# %%
import os
import xarray as xr
import numpy as np

# Define the folder containing the input files
input_folder = "/Users/lb962/Downloads/ESL/GESLA/notebooks/feature_extraction/API_calls/CoDEC/tides2014"

# Initialize an empty list to store processed datasets
processed_datasets = []

# Iterate over each file in the input folder
for filename in os.listdir(input_folder):
    print(filename)
    if filename.endswith(".nc"):  # Process only NetCDF files
        # Construct the full path to the input file
        input_file = os.path.join(input_folder, filename)
        
        # Process the file using the defined function
        processed_data = process_file(input_file, coastline_points)
        
        # Append the processed dataset to the list
        processed_datasets.append(processed_data)
# Out:
# historical_tide_2014_12_v1.nc
# historical_tide_2014_10_v1.nc
# historical_tide_2014_09_v1.nc
# historical_tide_2014_11_v1.nc
# historical_tide_2014_08_v1.nc
# historical_tide_2014_02_v1.nc
# historical_tide_2014_06_v1.nc
# historical_tide_2014_04_v1.nc
# historical_tide_2014_03_v1.nc
# historical_tide_2014_01_v1.nc
# historical_tide_2014_05_v1.nc
# historical_tide_2014_07_v1.nc

# %%
# Concatenate all processed datasets along the time dimension
concatenated_data = xr.concat(processed_datasets, dim='time')

# %%
concatenated_data
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 8760, stations: 2622)
# Coordinates:
#     longitude  (stations) float64 -5.076 -5.12 -2.161 ... 10.53 -3.025 -3.289
#     latitude   (stations) float64 48.45 48.46 49.27 49.27 ... 64.8 58.94 56.05
#   * stations   (stations) uint16 696 697 698 699 700 ... 41828 41950 43200 43390
#   * time       (time) datetime64[ns] 2014-12-01 ... 2014-07-31T23:00:00
# Data variables:
#     tide       (time, stations) float32 1.298 1.302 2.299 ... 0.7478 -1.777
# Attributes: (12/35)
#     Conventions:                   CF-1.6
#     featureType:                   timeSeries
#     id:                            GTSMv3_tides
#     naming_authority:              https://deltares.nl/en
#     Metadata_Conventions:          Unidata Dataset Discovery v1.0
#     title:                         10-minute timeseries of tide levels
#     ...                            ...
#     time_coverage_start:           2014-12-01 00:00:00
# ...

# %%
# Save the concatenated data to a new NetCDF file
output_file = "/Users/lb962/Downloads/ESL/GESLA/data/processed/CODEC/2014tidesv2.nc"
concatenated_data.to_netcdf(output_file)

# %% [markdown]
# 2005-2023

# %%
import os
import xarray as xr
import numpy as np

# Define the folder containing the input files for the years 2005 to 2013
input_folder_20052013 = "/Users/lb962/Downloads/ESL/GESLA/notebooks/feature_extraction/API_calls/CoDEC/tides2005-2013"

# Initialize an empty list to store processed datasets for the years 2005 to 2013
processed_datasets_20052013 = []

# Iterate over each file in the input folder for the years 2005 to 2013
for filename_20052013 in os.listdir(input_folder_20052013):
    print(filename_20052013)
    if filename_20052013.endswith(".nc"):  # Process only NetCDF files
        # Construct the full path to the input file for the years 2005 to 2013
        input_file_20052013 = os.path.join(input_folder_20052013, filename_20052013)
        
        # Process the file using the defined function for the years 2005 to 2013
        processed_data_20052013 = process_file(input_file_20052013, coastline_points)
        
        # Append the processed dataset to the list for the years 2005 to 2013
        processed_datasets_20052013.append(processed_data_20052013)

# Concatenate all processed datasets along the time dimension for the years 2005 to 2013
concatenated_data_20052013 = xr.concat(processed_datasets_20052013, dim='time')
# Out:
# historical_tide_2007_07_v1.nc
# historical_tide_2010_01_v1.nc
# historical_tide_2006_07_v1.nc
# historical_tide_2011_01_v1.nc
# historical_tide_2007_05_v1.nc
# historical_tide_2010_03_v1.nc
# historical_tide_2006_05_v1.nc
# historical_tide_2011_03_v1.nc
# historical_tide_2012_11_v1.nc
# historical_tide_2013_11_v1.nc
# historical_tide_2008_10_v1.nc
# historical_tide_2009_10_v1.nc
# historical_tide_2012_08_v1.nc
# historical_tide_2013_08_v1.nc
# historical_tide_2008_09_v1.nc
# historical_tide_2009_09_v1.nc
# historical_tide_2007_01_v1.nc
# historical_tide_2010_07_v1.nc
# historical_tide_2006_01_v1.nc
# historical_tide_2011_07_v1.nc
# historical_tide_2007_03_v1.nc
# historical_tide_2010_05_v1.nc
# historical_tide_2006_03_v1.nc
# historical_tide_2011_05_v1.nc
# historical_tide_2008_12_v1.nc
# historical_tide_2009_12_v1.nc
# historical_tide_2010_02_v1.nc
# historical_tide_2007_04_v1.nc
# historical_tide_2011_02_v1.nc
# historical_tide_2006_04_v1.nc
# historical_tide_2007_06_v1.nc
# ...

# %%
# Save the concatenated data to a new NetCDF file for the years 2005 to 2013
output_file_20052013 = "/Users/lb962/Downloads/ESL/GESLA/data/processed/CODEC/20052013tides.nc"
concatenated_data_20052013.to_netcdf(output_file_20052013)

# %% [markdown]
# 1998-2005

# %%
import os
import xarray as xr
import numpy as np

# Define the folder containing the input files for the years 1998 to 2005
input_folder_19982005 = "/Users/lb962/Downloads/ESL/GESLA/notebooks/feature_extraction/API_calls/CoDEC/tides1998-2005"

# Initialize an empty list to store processed datasets for the years 1998 to 2005
processed_datasets_19982005 = []

# Iterate over each file in the input folder for the years 1998 to 2005
for filename_19982005 in os.listdir(input_folder_19982005):
    print(filename_19982005)
    if filename_19982005.endswith(".nc"):  # Process only NetCDF files
        # Construct the full path to the input file for the years 1998 to 2005
        input_file_19982005 = os.path.join(input_folder_19982005, filename_19982005)
        
        # Process the file using the defined function for the years 1998 to 2005
        processed_data_19982005 = process_file(input_file_19982005, coastline_points)
        
        # Append the processed dataset to the list for the years 1998 to 2005
        processed_datasets_19982005.append(processed_data_19982005)

# Concatenate all processed datasets along the time dimension for the years 1998 to 2005
concatenated_data_19982005 = xr.concat(processed_datasets_19982005, dim='time')

# Save the concatenated data to a new NetCDF file for the years 1998 to 2005
output_file_19982005 = "/Users/lb962/Downloads/ESL/GESLA/data/processed/CODEC/19982005tides.nc"
concatenated_data_19982005.to_netcdf(output_file_19982005)

# %% [markdown]
# ## 1990-1997

# %%
import os
import xarray as xr
import numpy as np

# Define the folder containing the input files for the years 1990 to 1997
input_folder_19901997 = "/Users/lb962/Downloads/ESL/GESLA/notebooks/feature_extraction/API_calls/CoDEC/tides1990-1997"

# Initialize an empty list to store processed datasets for the years 1990 to 1997
processed_datasets_19901997 = []

# Iterate over each file in the input folder for the years 1990 to 1997
for filename_19901997 in os.listdir(input_folder_19901997):
    print(filename_19901997)
    if filename_19901997.endswith(".nc"):  # Process only NetCDF files
        # Construct the full path to the input file for the years 1990 to 1997
        input_file_19901997 = os.path.join(input_folder_19901997, filename_19901997)
        
        # Process the file using the defined function for the years 1990 to 1997
        processed_data_19901997 = process_file(input_file_19901997, coastline_points)
        
        # Append the processed dataset to the list for the years 1990 to 1997
        processed_datasets_19901997.append(processed_data_19901997)

# Concatenate all processed datasets along the time dimension for the years 1990 to 1997
concatenated_data_19901997 = xr.concat(processed_datasets_19901997, dim='time')

# Save the concatenated data to a new NetCDF file for the years 1990 to 1997
output_file_19901997 = "/Users/lb962/Downloads/ESL/GESLA/data/processed/CODEC/19901997tides.nc"
concatenated_data_19901997.to_netcdf(output_file_19901997)

# %% [markdown]
# #1982 1989

# %%
# Define the folder containing the input files for the years 1982 to 1989
input_folder_19821989 = "/Users/lb962/Downloads/ESL/GESLA/notebooks/feature_extraction/API_calls/CoDEC/tides1982-1989"

# Initialize an empty list to store processed datasets for the years 1982 to 1989
processed_datasets_19821989 = []

# Iterate over each file in the input folder for the years 1982 to 1989
for filename_19821989 in os.listdir(input_folder_19821989):
    print(filename_19821989)
    if filename_19821989.endswith(".nc"):  # Process only NetCDF files
        # Construct the full path to the input file for the years 1982 to 1989
        input_file_19821989 = os.path.join(input_folder_19821989, filename_19821989)
        
        # Process the file using the defined function for the years 1982 to 1989
        processed_data_19821989 = process_file(input_file_19821989, coastline_points)
        
        # Append the processed dataset to the list for the years 1982 to 1989
        processed_datasets_19821989.append(processed_data_19821989)

# Concatenate all processed datasets along the time dimension for the years 1982 to 1989
concatenated_data_19821989 = xr.concat(processed_datasets_19821989, dim='time')

# Save the concatenated data to a new NetCDF file for the years 1982 to 1989
output_file_19821989 = "/Users/lb962/Downloads/ESL/GESLA/data/processed/CODEC/19821989tides.nc"
concatenated_data_19821989.to_netcdf(output_file_19821989)

# %% [markdown]
# # 19741981

# %%
import os
import xarray as xr
import numpy as np

# Define the folder containing the input files for the years 1974 to 1981
input_folder_19741981 = "/Users/lb962/Downloads/ESL/GESLA/notebooks/feature_extraction/API_calls/CoDEC/tides1974-1981"

# Initialize an empty list to store processed datasets for the years 1974 to 1981
processed_datasets_19741981 = []

# Iterate over each file in the input folder for the years 1974 to 1981
for filename_19741981 in os.listdir(input_folder_19741981):
    print(filename_19741981)
    if filename_19741981.endswith(".nc"):  # Process only NetCDF files
        # Construct the full path to the input file for the years 1974 to 1981
        input_file_19741981 = os.path.join(input_folder_19741981, filename_19741981)
        
        # Process the file using the defined function for the years 1974 to 1981
        processed_data_19741981 = process_file(input_file_19741981, coastline_points)
        
        # Append the processed dataset to the list for the years 1974 to 1981
        processed_datasets_19741981.append(processed_data_19741981)

# Concatenate all processed datasets along the time dimension for the years 1974 to 1981
concatenated_data_19741981 = xr.concat(processed_datasets_19741981, dim='time')

# Save the concatenated data to a new NetCDF file for the years 1974 to 1981
output_file_19741981 = "/Users/lb962/Downloads/ESL/GESLA/data/processed/CODEC/19741981tides.nc"
concatenated_data_19741981.to_netcdf(output_file_19741981)

# %% [markdown]
# # 19661973

# %%
import os
import xarray as xr
import numpy as np

# Define the folder containing the input files for the years 1966 to 1973
input_folder_19661973 = "/Users/lb962/Downloads/ESL/GESLA/notebooks/feature_extraction/API_calls/CoDEC/tides1966-1973"

# Initialize an empty list to store processed datasets for the years 1966 to 1973
processed_datasets_19661973 = []

# Iterate over each file in the input folder for the years 1966 to 1973
for filename_19661973 in os.listdir(input_folder_19661973):
    print(filename_19661973)
    if filename_19661973.endswith(".nc"):  # Process only NetCDF files
        # Construct the full path to the input file for the years 1966 to 1973
        input_file_19661973 = os.path.join(input_folder_19661973, filename_19661973)
        
        # Process the file using the defined function for the years 1966 to 1973
        processed_data_19661973 = process_file(input_file_19661973, coastline_points)
        
        # Append the processed dataset to the list for the years 1966 to 1973
        processed_datasets_19661973.append(processed_data_19661973)

# Concatenate all processed datasets along the time dimension for the years 1966 to 1973
concatenated_data_19661973 = xr.concat(processed_datasets_19661973, dim='time')

# Save the concatenated data to a new NetCDF file for the years 1966 to 1973
output_file_19661973 = "/Users/lb962/Downloads/ESL/GESLA/data/processed/CODEC/19661973tides.nc"
concatenated_data_19661973.to_netcdf(output_file_19661973)

# %% [markdown]
# #19581965

# %%
import os
import xarray as xr
import numpy as np

# Define the folder containing the input files for the years 1958 to 1965
input_folder_19581965 = "/Users/lb962/Downloads/ESL/GESLA/notebooks/feature_extraction/API_calls/CoDEC/tides1958-1965"

# Initialize an empty list to store processed datasets for the years 1958 to 1965
processed_datasets_19581965 = []

# Iterate over each file in the input folder for the years 1958 to 1965
for filename_19581965 in os.listdir(input_folder_19581965):
    print(filename_19581965)
    if filename_19581965.endswith(".nc"):  # Process only NetCDF files
        # Construct the full path to the input file for the years 1958 to 1965
        input_file_19581965 = os.path.join(input_folder_19581965, filename_19581965)
        
        # Process the file using the defined function for the years 1958 to 1965
        processed_data_19581965 = process_file(input_file_19581965, coastline_points)
        
        # Append the processed dataset to the list for the years 1958 to 1965
        processed_datasets_19581965.append(processed_data_19581965)

# Concatenate all processed datasets along the time dimension for the years 1958 to 1965
concatenated_data_19581965 = xr.concat(processed_datasets_19581965, dim='time')

# Save the concatenated data to a new NetCDF file for the years 1958 to 1965
output_file_19581965 = "/Users/lb962/Downloads/ESL/GESLA/data/processed/CODEC/19581965tides.nc"
concatenated_data_19581965.to_netcdf(output_file_19581965)

# %% [markdown]
# #19501958

# %%
import os
import xarray as xr
import numpy as np

# Define the folder containing the input files for the years 1950 to 1958
input_folder_19501958 = "/Users/lb962/Downloads/ESL/GESLA/notebooks/feature_extraction/API_calls/CoDEC/tides1950-1958"

# Initialize an empty list to store processed datasets for the years 1950 to 1958
processed_datasets_19501958 = []

# Iterate over each file in the input folder for the years 1950 to 1958
for filename_19501958 in os.listdir(input_folder_19501958):
    print(filename_19501958)
    if filename_19501958.endswith(".nc"):  # Process only NetCDF files
        # Construct the full path to the input file for the years 1950 to 1958
        input_file_19501958 = os.path.join(input_folder_19501958, filename_19501958)
        
        # Process the file using the defined function for the years 1950 to 1958
        processed_data_19501958 = process_file(input_file_19501958, coastline_points)
        
        # Append the processed dataset to the list for the years 1950 to 1958
        processed_datasets_19501958.append(processed_data_19501958)

# Concatenate all processed datasets along the time dimension for the years 1950 to 1958
concatenated_data_19501958 = xr.concat(processed_datasets_19501958, dim='time')

# Save the concatenated data to a new NetCDF file for the years 1950 to 1958
output_file_19501958 = "/Users/lb962/Downloads/ESL/GESLA/data/processed/CODEC/19501958tides.nc"
concatenated_data_19501958.to_netcdf(output_file_19501958)

# %% [markdown]
# # plot tides

# %%
# Define the input file path
input_file = '/Users/lb962/Downloads/ESL/GESLA/notebooks/feature_extraction/API_calls/CoDEC/tides1950-1958/historical_tide_1950_01_v1.nc'
file1 = process_file(input_file, coastline_points)

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

desired_time = '2014-04-30T23:00:00.000000000'

# Extract latitude and longitude values from the selected_data xarray dataset
selected_lon_values =concatenated_data['longitude'].values
selected_lat_values = concatenated_data['latitude'].values

# Create a figure and axis with a specific projection
plt.figure(figsize=(10, 6))
ax = plt.axes(projection=ccrs.PlateCarree())

# Plot tide at the desired time for selected data
plt.scatter(selected_lon_values, selected_lat_values, c=concatenated_data['tide'].sel(time=desired_time).values, cmap='Blues')

# Add colorbar
plt.colorbar(label='Tide')

# Plot land outlines on top
ax.add_feature(cfeature.LAND, edgecolor='black', zorder=2)

# Add labels and title
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title(f'Tide at {desired_time} (Selected range)')

# Show plot
plt.show()

# %%
import xarray as xr

# Define the input file path
input_file = '/Users/lb962/Downloads/ESL/GESLA/notebooks/feature_extraction/API_calls/CoDEC/tides1950-1958/historical_tide_1950_01_v1.nc'

# Open the NetCDF file using xarray
ds = xr.open_dataset(input_file)

# Rename station_y_coordinate to latitude and station_x_coordinate to longitude
ds = ds.rename({'station_y_coordinate': 'latitude', 'station_x_coordinate': 'longitude'})

# Extract longitude and latitude coordinates
lon_values = ds['longitude'].values
lat_values = ds['latitude'].values

# Define the longitude and latitude range for Europe
#lon_min, lon_max = -11.5, 35.0  # Longitude range for Europe
#lat_min, lat_max = 29.5, 71.0   # Latitude range for Europe

# Define the longitude and latitude range for Europe
lon_min, lon_max = -11.5, 15.0  # Longitude range for Europe
lat_min, lat_max = 48, 65.0   # Latitude range for Europe

# Boolean indexing to select the desired range
selected_indices = (lon_values >= lon_min) & (lon_values <= lon_max) & (lat_values >= lat_min) & (lat_values <= lat_max)
selected_data = ds.isel(stations=selected_indices)

# Extract longitude and latitude coordinates for selected data
lon_selected = selected_data['longitude'].values
lat_selected = selected_data['latitude'].values

# %%
import numpy as np

# Define the interpolation interval (in meters)
interpolation_interval = 0.01  # Adjust as needed

# Function to interpolate points along a line segment
def interpolate_segment(segment):
    # Calculate the length of the segment
    segment_length = segment.length
    # Calculate the number of interpolation points for the segment
    num_points = int(segment_length / interpolation_interval) + 1
    # Interpolate points along the segment at intervals of 100 meters
    interpolated_points = [segment.interpolate(i * interpolation_interval) for i in range(num_points)]
    return interpolated_points

# Interpolate points along each line segment of the MULTILINESTRING
coastline_points = []
for line in coastline.geometry:
    if line.geom_type == 'LineString':
        # If the geometry is a LineString, interpolate points along it
        coastline_points.extend(interpolate_segment(line))
    elif line.geom_type == 'MultiLineString':
        # If the geometry is a MultiLineString, iterate over its components and interpolate points along each segment
        for segment in line.geoms:
            coastline_points.extend(interpolate_segment(segment))

# Convert the coastline points to a GeoSeries
coastline_points = gpd.GeoSeries(coastline_points)

# %%
# Create arrays for longitude and latitude coordinates of coastline points
coastline_lon = coastline_points.x.values
coastline_lat = coastline_points.y.values

# Get longitude and latitude values from the xarray dataset
lon_values = selected_data['longitude'].values
lat_values = selected_data['latitude'].values

# Repeat coastline coordinates to match the shape of lon_values and lat_values
coastline_lon_rep = np.repeat(coastline_lon[:, np.newaxis], len(lon_values), axis=1)
coastline_lat_rep = np.repeat(coastline_lat[:, np.newaxis], len(lat_values), axis=1)

# Calculate distances between each point in the dataset and each coastline point
distances = np.sqrt((lon_values - coastline_lon_rep)**2 + (lat_values - coastline_lat_rep)**2)

# Find the minimum distance for each point in the dataset
min_distances = np.min(distances, axis=0)

# Define a threshold distance within which points are considered close to the coastline
threshold_distance = 0.05  # Adjust as needed 0.05

# Create a mask to select points close to the coastline
coastline_mask = min_distances < threshold_distance

# Use the mask to select coastline points in the original dataset
coastline_data = selected_data.isel(stations=coastline_mask)

# %%
coastline_data
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 4464, stations: 2622)
# Coordinates:
#     longitude  (stations) float64 -5.076 -5.12 -2.161 ... 10.53 -3.025 -3.289
#     latitude   (stations) float64 48.45 48.46 49.27 49.27 ... 64.8 58.94 56.05
#   * time       (time) datetime64[ns] 1950-01-01 ... 1950-01-31T23:50:00
#   * stations   (stations) uint16 696 697 698 699 700 ... 41828 41950 43200 43390
# Data variables:
#     tide       (time, stations) float32 ...
# Attributes: (12/35)
#     Conventions:                   CF-1.6
#     featureType:                   timeSeries
#     id:                            GTSMv3_tides
#     naming_authority:              https://deltares.nl/en
#     Metadata_Conventions:          Unidata Dataset Discovery v1.0
#     title:                         10-minute timeseries of tide levels
#     ...                            ...
#     time_coverage_start:           1950-01-01 00:00:00
#     time_coverage_end:             1950-01-31 23:50:00
#     experiment:
# ...

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

desired_time = '1950-01-30T23:40:00.000000000'

# Extract latitude and longitude values from the selected_data xarray dataset
selected_lon_values = coastline_data['longitude'].values
selected_lat_values = coastline_data['latitude'].values

# Create a figure and axis with a specific projection
plt.figure(figsize=(10, 6))
ax = plt.axes(projection=ccrs.PlateCarree())

# Plot tide at the desired time for selected data
plt.scatter(selected_lon_values, selected_lat_values, c=coastline_data['tide'].sel(time=desired_time).values, cmap='Blues')

# Add colorbar
plt.colorbar(label='Tide')

# Plot land outlines on top
ax.add_feature(cfeature.LAND, edgecolor='black', zorder=2)

# Add labels and title
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title(f'Tide at {desired_time} (Selected range)')

# Show plot
plt.show()

# %%
ds_hourly = coastline_data.resample(time='1H').mean()

# %%
yo = ds_hourly

# %%
ds_hourly
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 744, stations: 1606)
# Coordinates:
#     longitude  (stations) float64 -5.076 -5.12 -2.087 ... -5.193 10.53 -3.289
#     latitude   (stations) float64 48.45 48.46 49.17 49.17 ... 58.38 64.8 56.05
#   * stations   (stations) uint16 696 697 701 702 703 ... 41826 41828 41950 43390
#   * time       (time) datetime64[ns] 1950-01-01 ... 1950-01-31T23:00:00
# Data variables:
#     tide       (time, stations) float32 -0.05867 -0.05867 ... 0.456 0.8465
# Attributes: (12/35)
#     Conventions:                   CF-1.6
#     featureType:                   timeSeries
#     id:                            GTSMv3_tides
#     naming_authority:              https://deltares.nl/en
#     Metadata_Conventions:          Unidata Dataset Discovery v1.0
#     title:                         10-minute timeseries of tide levels
#     ...                            ...
#     time_coverage_start:           1950-01-01 00:00:00
# ...

# %%
merged_ds = xr.merge([ds_hourly, yo])

# %%
import xarray as xr
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

def select_european_data(ds):
    # Rename station_y_coordinate to latitude and station_x_coordinate to longitude
    ds = ds.rename({'station_y_coordinate': 'latitude', 'station_x_coordinate': 'longitude'})

    # Extract longitude and latitude coordinates
    lon_values = ds['longitude'].values
    lat_values = ds['latitude'].values

    # Define the longitude and latitude range for Europe
    lon_min, lon_max = -11.5, 15.0  # Longitude range for Europe
    lat_min, lat_max = 48, 65.0   # Latitude range for Europe

    # Boolean indexing to select the desired range
    selected_indices = (lon_values >= lon_min) & (lon_values <= lon_max) & (lat_values >= lat_min) & (lat_values <= lat_max)
    selected_data = ds.isel(stations=selected_indices)
    
    ds_hourly = selected_data
    # Resample the dataset to hourly intervals by taking the mean of each hourly period
    #ds_hourly = selected_data.resample(time='1H').mean()

    # Extract longitude and latitude coordinates for selected data
    lon_selected = ds_hourly['longitude'].values
    lat_selected = ds_hourly['latitude'].values

    return ds_hourly, lon_selected, lat_selected

import xarray as xr

# Define the input file path
input_file = '/Users/lb962/Downloads/ESL/GESLA/notebooks/feature_extraction/API_calls/CoDEC/tides1950-1958/historical_tide_1950_01_v1.nc'

# Open the NetCDF file using xarray
ds = xr.open_dataset(input_file)

# Usage example:
selected_data, lon_selected, lat_selected = select_european_data(ds)

# %%
selected_data
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 4464, stations: 5450)
# Coordinates:
#     longitude  (stations) float64 -5.076 -5.12 -2.161 ... 10.53 -3.025 -3.289
#     latitude   (stations) float64 48.45 48.46 49.27 49.27 ... 64.8 58.94 56.05
#   * time       (time) datetime64[ns] 1950-01-01 ... 1950-01-31T23:50:00
#   * stations   (stations) uint16 696 697 698 699 700 ... 41828 41950 43200 43390
# Data variables:
#     tide       (time, stations) float32 ...
# Attributes: (12/35)
#     Conventions:                   CF-1.6
#     featureType:                   timeSeries
#     id:                            GTSMv3_tides
#     naming_authority:              https://deltares.nl/en
#     Metadata_Conventions:          Unidata Dataset Discovery v1.0
#     title:                         10-minute timeseries of tide levels
#     ...                            ...
#     time_coverage_start:           1950-01-01 00:00:00
#     time_coverage_end:             1950-01-31 23:50:00
#     experiment:
# ...

# %%
# Resample the dataset to hourly intervals by taking the mean of each hourly period
ds_hourly2 = selected_data.resample(time='1H').mean()
ds_hourly2

# %%
# Create a figure and axis with a specific projection
plt.figure(figsize=(10, 6))
ax = plt.axes(projection=ccrs.PlateCarree())
time = "1950-01-31T23:00:00"

# Plot tide at the desired time for selected data
plt.scatter(lon_selected, lat_selected, c=selected_data['tide'].sel(time=time).values, cmap='viridis')

# Add colorbar
plt.colorbar(label='Tide')

# Plot land outlines on top
ax.add_feature(cfeature.LAND, edgecolor='black', zorder=2)

# Add labels and title
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title(f'Tide at {time} (Selected range)')

# Show plot
plt.show()

# %%
# Resample the dataset to hourly intervals by taking the mean of each hourly period
ds_hourly = selected_data.resample(time='1H').mean()

# %%
ds_hourly

# %%
ds_hourly
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 744, stations: 43119)
# Coordinates:
#     longitude  (stations) float64 24.09 24.09 26.9 26.89 ... 139.1 37.75 37.95
#     latitude   (stations) float64 34.83 34.87 35.37 35.4 ... 34.2 -46.98 -46.63
#   * stations   (stations) uint16 0 1 2 3 4 5 ... 43729 43730 43731 43732 43733
#   * time       (time) datetime64[ns] 1950-01-01 ... 1950-01-31T23:00:00
# Data variables:
#     tide       (time, stations) float32 -0.05533 -0.05517 -0.048 ... 0.026 0.047
# Attributes: (12/35)
#     Conventions:                   CF-1.6
#     featureType:                   timeSeries
#     id:                            GTSMv3_tides
#     naming_authority:              https://deltares.nl/en
#     Metadata_Conventions:          Unidata Dataset Discovery v1.0
#     title:                         10-minute timeseries of tide levels
#     ...                            ...
#     time_coverage_start:           1950-01-01 00:00:00
# ...

# %%
# Resample the dataset to hourly intervals by taking the mean of each hourly period
ds_hourly2 = selected_data.resample(time='1H')

# %%
ds_hourly2
# Out:
# DatasetResample, grouped over '__resample_dim__'
# 744 groups with labels 1950-01-01, ..., 1950-01-31T2....

# %%
import os
import xarray as xr

def select_and_merge_data(folder_path, lon_min=-11.5, lon_max=35.0, lat_min=29.5, lat_max=71.0):
    # List all files in the folder
    file_list = [os.path.join(folder_path, file) for file in os.listdir(folder_path) if file.endswith('.nc')]

    # Initialize an empty list to store selected datasets
    selected_datasets = []

    # Iterate over each file
    for file_path in file_list:
        # Open the NetCDF file using xarray
        ds = xr.open_dataset(file_path)

        # Rename station_y_coordinate to latitude and station_x_coordinate to longitude
        ds = ds.rename({'station_y_coordinate': 'latitude', 'station_x_coordinate': 'longitude'})

        # Extract longitude and latitude coordinates
        lon_values = ds['longitude'].values
        lat_values = ds['latitude'].values

        # Boolean indexing to select the desired range
        selected_indices = (lon_values >= lon_min) & (lon_values <= lon_max) & (lat_values >= lat_min) & (lat_values <= lat_max)
        selected_data = ds.isel(stations=selected_indices)

        # Append selected dataset to the list
        selected_datasets.append(selected_data)

        # Merge all selected datasets along the 'time' dimension
        #merged_data = xr.concat(selected_datasets, dim='time')
        #print(merged_data)
    return selected_datasets

# %%
# Define the folder path containing the NetCDF files
folder_path = '/Users/lb962/Downloads/ESL/GESLA/notebooks/feature_extraction/API_calls/CoDEC/check'

# Call the function to select and merge data
merged_data = select_and_merge_data(folder_path)
len(merged_data)
# Save the merged data as a new NetCDF file
#output_file = '/Users/lb962/Downloads/ESL/GESLA/notebooks/feature_extraction/API_calls/CoDEC/merged_tides/check.nc'
#merged_data.to_netcdf(output_file)
# Out:
# 2

# %%
merged_data

# %%
merged_ds = xr.merge(merged_data)

# %%
# !cdo mergetime /Users/lb962/Downloads/ESL/GESLA/notebooks/feature_extraction/API_calls/CoDEC/check/*nc /Users/lb962/Downloads/ESL/GESLA/notebooks/feature_extraction/API_calls/CoDEC/check/merged.nc
# Out:
# ^C

# %%
hallo_data = xr.concat(merged_data, dim='time')

# %%
# !cdo mergetime */*.nc merged_file.nc
# Out:
# cdo    mergetime: Variable u10 not found in first input stream!
# cdo    mergetime: Variable v10 not found in first input stream!
# cdo    mergetime: Variable mwd not found in first input stream!
# cdo    mergetime: Variable swh not found in first input stream!
#
# cdo    mergetime (Abort): Input streams have different number of variables per timestep!

# %%
import glob
import xarray as xr

# Search for all files matching the pattern
file_list = glob.glob('API_calls/CoDEC/*/*.nc')

datasets = [xr.open_dataset(file) for file in file_list]

# Concatenate along time dimension
merged_data = xr.concat(datasets, dim='time')

# Save merged data to a new netCDF file
merged_data.to_netcdf('merged_file.nc')
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import glob
import xarray as xr

# Search for all files matching the pattern
file_list = glob.glob('API_calls/CoDEC/*/*.nc')

# Define batch size
batch_size = 10

# Iterate over file list in batches
for i in range(0, len(file_list), batch_size):
    batch_files = file_list[i:i+batch_size]
    datasets = [xr.open_dataset(file) for file in batch_files]

    # Concatenate along time dimension
    merged_data = xr.concat(datasets, dim='time')

    # Save merged data to a new netCDF file
    merged_data.to_netcdf(f'processed/merged_file_batch_{i}.nc')
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
